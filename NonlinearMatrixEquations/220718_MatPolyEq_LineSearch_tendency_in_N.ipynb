# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

# from jupyterthemes import jtplot
# jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)
delt = .00001
m = 10
A = shf.MakeGenSingA(m, 6, delta = delt)

# A = np.load('200121_Coefficients.npy')

# %%
Ss = shf.NewtonPoly(A)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.set_title('Time = {:.10f}'.format(Ss['CalTime']))
ax.semilogy(Ss['errs'], '-or')

# %%
S = Ss['sol']
s = np.reshape(S, (np.prod(S.shape),), order='F')
P_S = Ss['P_Xs'][-1]
d, X = nla.eig(P_S)
imin = np.argmin(np.abs(d))
e = d[imin]
x = X[:,imin]
a = nla.inv(X) @ s
Pns = a[imin] * x

# %%
plt.plot(np.real((nla.inv(X) @ (P_S + .1*np.eye(P_S.shape[0])) @ X)[np.diag_indices(100)] - d), '.')
plt.ylim([-.5, .5])
# Out:
# (-0.5, 0.5)

# %%
plt.plot(np.imag((nla.inv(X) @ (P_S + .1*np.eye(P_S.shape[0])) @ X)[np.diag_indices(100)] - d), '.')
plt.ylim([-1, 1])
# Out:
# (-1.0, 1.0)

# %%
xx = np.real(np.reshape(np.sign(x[0])*x, S.shape, order = 'F'))
print(xx)
X0 = S - xx
print(X0)

P_X0 = np.zeros(P_S.shape)
for k in range(1, A.shape[0]):
    for l in range(k):
        P_X0 = P_X0 + np.kron(nla.matrix_power(X0.transpose(),k-l-1), A[k,:,:] @ nla.matrix_power(X0, l))
vP = np.reshape(shf.Pnomial(X0, A), m**2, 'F') # Reshape는 반드시 Fortran 방식으로
h = nla.solve(P_X0, vP)
H = np.reshape(h, S.shape, order = 'F')
X1 = X0 - H
x1s = np.reshape(S - X1, (np.prod(S.shape),), order='F')
a = nla.inv(X) @ x1s
Pnx1s = a[imin] * x
print(X1)
print(S - X1)
print(np.real(np.reshape(Pnx1s, S.shape, order='F')))
print(S - X1 - np.real(np.reshape(Pnx1s, S.shape, order='F')))
print(nla.norm(Pnx1s - x1s))
# Out:
# [[0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]
#  [0.13389363 0.06808498 0.10444005 0.09172606 0.1192882  0.10146492 0.1012751  0.08155439 0.08205555 0.09974895]]
# [[-0.08766948  0.02156607  0.03020256 -0.039984    0.06772335  0.03447195  0.06668465 -0.03739448 -0.00272855 -0.03645115]
#  [ 0.02514505 -0.04458506 -0.01226905  0.06819869 -0.07558413 -0.06007135  0.04408252  0.00741009 -0.00150675  0.06560091]
#  [-0.02987887 -0.00931508 -0.0682613  -0.02478105  0.03428179  0.02803775 -0.04182554  0.05968086  0.01992587  0.04855648]
#  [ 0.05125288 -0.03304675 -0.03642707 -0.06007488  0.01412962  0.06411886  0.07387999 -0.04854266  0.05009915 -0.05896821]
#  [ 0.01982789  0.02940384  0.05958455  0.01629838 -0.07820033  0.00677546 -0.04009943  0.02050257 -0.04624558  0.02857356]
#  [ 0.0080791   0.08658056  0.06729565 -0.02761346  0.03376237 -0.06626514 -0.04631793  0.04128711 -0.03269575 -0.04769159]
#  [-0.00972945 -0.03693937 -0.04351286  0.03431794  0.03372112  0.03590674 -0.06641197  0.0438887  -0.00175835  0.02693843]
#  [ 0.04003406 -0.03994025 -0.06038045  0.05379717 -0.06545871  0.01516962  0.03289395 -0.05358159  0.02519445  0.06869268]
#  [ 0.02851789 -0.00428229  0.06698745 -0.00801324  0.00347241 -0.0634562   0.05841717 -0.03577166 -0.05383179  0.02438119]
#  [ 0.0284688   0.00328278 -0.01127408  0.03977249  0.00703647 -0.01424    -0.03952546  0.00287179  0.06529867 -0.06527055]]
