# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

from jupyterthemes import jtplot
jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)

A = shf.MakeGenSingA(5, 2, delta = .00000)

# A = np.load('200121_Coefficients.npy')

# %%
LSiter = 6
Ss = [None] * 8
Ss[0] = shf.NewtonPoly(A)
S = Ss[0]['sol']
Alist = []
for i, e in zip(range(1,8), 10. ** np.arange(-7,0)):
    A0 = np.copy(A)
    Alist.append(A0)
#     A0[0,:,:] += e*S
#     A0[1,:,:] -= e*np.eye(A.shape[1])
    A0[0,:,:] -= e*S
    A0[1,:,:] += e*np.eye(A.shape[1])
    Ss[i] = shf.NewtonPoly(A0)

# %%
indice = range(8)
il = len(indice)
xmax = max([len(Ss[i]['Xs']) for i in indice])
fig = plt.figure(figsize=(30,15))
ax = [None] * il
for i in indice:
    ax[i] = fig.add_subplot(2,il//2,i+1)
    ax[i].semilogy(Ss[i]['errs'],'-o')
#     ax[i].set_title(titlelist[i])
    ax[i].set_ylim([1e-16, 1e1])
    ax[i].set_xlim([-1, xmax])
    if i > 0:
        ax[i].set_xlim(ax[0].get_xlim())

# if len(Ss[0]['Hs']) >= 6:
#     print('{} - {} = {}'.format(Ss[2]['lamb'][LSiter], Ss[3]['lamb'][LSiter], Ss[2]['lamb'][LSiter] - Ss[3]['lamb'][LSiter]))
#     print('{} - {} = {}'.format(Ss[3]['lamb'][LSiter], Ss[4]['lamb'][LSiter], Ss[3]['lamb'][LSiter] - Ss[4]['lamb'][LSiter]))

# %%
print('Finished')
# Out:
# Finished

# %%
eX = np.zeros((np.prod(A.shape[1:]), il))
for i in indice:
    d, X = nla.eig(Ss[i]['P_Xs'][-1])
    j = np.argmin(np.abs(d))
    if i != 0 and np.sign(eX[0,0]) != np.sign(np.real(X[0,j])):
        eX[:,i] = -X[:,j]
    else:
        eX[:,i] = X[:,j]
print(eX)
# Out:
# [[-0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956]
#  [-0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956]
#  [-0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956]
#  [-0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956]
#  [-0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956 -0.21051956]
#  [-0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356]
#  [-0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356]
#  [-0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356]
#  [-0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356]
#  [-0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356 -0.17832356]
#  [-0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807]
#  [-0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807]
#  [-0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807]
#  [-0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807]
#  [-0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807 -0.15324807]
#  [-0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523]
#  [-0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523]
#  [-0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523]
#  [-0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523]
#  [-0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523 -0.25903523]
#  [-0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739]
#  [-0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739]
#  [-0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739]
#  [-0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739]
#  [-0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739 -0.18247739]]
# c:\users\camp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:8: ComplexWarning: Casting complex values to real discards the imaginary part
#
# c:\users\camp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
for i in indice:
    if i != 0:
        print(nla.norm(Ss[0]['sol'] - Ss[i]['sol'], 'fro'))
        print(Ss[0]['sol'] - Ss[i]['sol'])
# print(A[0:2,:,:])
# print(Ss[7]['Xs'])
# Out:
# 1.0094299482526685e-08
# [[-2.12504747e-09 -1.80005152e-09 -1.54693194e-09 -2.61477928e-09 -1.84198146e-09]
#  [-2.12504744e-09 -1.80005148e-09 -1.54693193e-09 -2.61477917e-09 -1.84198140e-09]
