# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
from matplotlib import pyplot as plt
from time import time
import SHFunctions as shf
import os

# %% [markdown]
#     A = shf.MakeStochA(8,2)
#     Ss = shf.NewtonPoly(A)
#
#     ax = plt.subplot(111)
#     ax.semilogy(Ss['errs'],'-o')

# %%
    A = shf.MakeSingularA(8, 2, delta = .00)
    Ss = shf.NewtonPoly(A)

    ax = plt.subplot(111)
    ax.semilogy(Ss['errs'],'-o')

# %%
# S - X_{i}와 X_{i+1} - X_{i}의 Frobenius norm 구하기
nSmX = []
for X in Ss['Xs']:
    nSmX.append(nla.norm(Ss['sol'] - X,'fro'))

nXmX = []
for i in range(len(Ss['Xs'])-1):
    nXmX.append(nla.norm(Ss['Xs'][i+1] - Ss['Xs'][i],'fro'))

# %%
# 그래프로 S - X_{i}와 X_{i+1} - X_{i} 비교
fig, axes = plt.subplots(2,2,figsize=(14, 14))
axes[0,0].semilogy(nSmX,'-ob')
axes[0,1].semilogy(nXmX,'-or')
axes[1,0].semilogy(nSmX,'-ob')
axes[1,0].semilogy(nXmX,'-or')
