# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

from jupyterthemes import jtplot
jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)
delt = 1e-1
m = 5
A = shf.MakeGenSingA(m, 2, delta = delt)

# A = np.load('200121_Coefficients.npy')

# %%
Ss = shf.NewtonPoly(A)

# %%
fig = plt.figure(figsize=(8,8))
# ax = [[None] * m] * m
ax = fig.add_subplot(1, 1, 1)
ax.semilogy(Ss['errs'], '-bo')

# %%
P_X = Ss['P_Xs'][-1]
d, X = nla.eig(-P_X)
u, s, v = nla.svd(-P_X)
em1 = np.min(np.abs(d))
d1 = np.concatenate((d[0:np.argmin(d)],d[np.argmin(d)+1:]))
em2 = np.min(np.abs(d1))
sm1 = np.min(np.abs(s))
s1 = np.concatenate((s[0:np.argmin(s)],s[np.argmin(s)+1:]))
sm2 = np.min(np.abs(s1))
print(em1, em2, sm1, sm2)
# Out:
# 0.10000000201813794 0.41836497309428883 0.09848733952356784 0.40377047964348156
