# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

from jupyterthemes import jtplot
jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)

A = shf.MakeGenSingA(5, 2, delta = .00001)

# A = np.load('200121_Coefficients.npy')

# %%
LSiter = 6
Ss = [None] * 8 * 2
Ss[0] = shf.NewtonPoly(A)
Ss[8] = shf.NewtonPoly(A, X0 = np.ones(A.shape[1:]))
S = Ss[0]['sol']
Alist = []
for i, e in zip(range(1,8), 10. ** np.arange(-7,0)):
    A0 = np.copy(A)
    Alist.append(A0)
#     A0[0,:,:] += e*S
#     A0[1,:,:] -= e*np.eye(A.shape[1])
    A0[0,:,:] -= e*S
    A0[1,:,:] += e*np.eye(A.shape[1])
    Ss[i] = shf.NewtonPoly(A0)
    Ss[i+8] = shf.NewtonPoly(A0, X0 = np.ones(A.shape[1:]))

# %%
indice = range(8)
il = len(indice)
xmax = max([len(Ss[i]['Xs']) for i in indice])
fig = plt.figure(figsize=(32,8))
ax = [None] * il * 2
for i in indice:
    ax[i] = fig.add_subplot(2,il,i+1)
    ax[i].semilogy(Ss[i]['errs'],'-o')
    ax[i].set_ylim([1e-16, 1e1])
    ax[i].set_xlim([-1, xmax])
    ax[i+8] = fig.add_subplot(2,il,i+9)
    ax[i+8].semilogy(Ss[i]['errs'],'-o')
    ax[i+8].set_ylim([1e-16, 1e1])
    ax[i+8].set_xlim([-1, xmax])
    if i > 0:
        ax[i].set_xlim(ax[0].get_xlim())
        ax[i+8].set_xlim(ax[8].get_xlim())
# if len(Ss[0]['Hs']) >= 6:
#     print('{} - {} = {}'.format(Ss[2]['lamb'][LSiter], Ss[3]['lamb'][LSiter], Ss[2]['lamb'][LSiter] - Ss[3]['lamb'][LSiter]))
#     print('{} - {} = {}'.format(Ss[3]['lamb'][LSiter], Ss[4]['lamb'][LSiter], Ss[3]['lamb'][LSiter] - Ss[4]['lamb'][LSiter]))

# %%
print('Finished')
# Out:
# Finished

# %%
eX = np.zeros((np.prod(A.shape[1:]), il))
for i in indice:
    d, X = nla.eig(Ss[i]['P_Xs'][-1])
    j = np.argmin(np.abs(d))
    if i != 0 and np.sign(eX[0,0]) != np.sign(np.real(X[0,j])):
        eX[:,i] = -X[:,j]
    else:
        eX[:,i] = X[:,j]
print(eX)
# Out:
# [[0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253]
#  [0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253]
#  [0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253]
#  [0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253]
#  [0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253 0.22493253]
#  [0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536]
#  [0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536]
#  [0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536]
#  [0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536]
#  [0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536 0.24831536]
#  [0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365]
#  [0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365]
#  [0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365]
#  [0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365]
#  [0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365 0.26423365]
#  [0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262]
#  [0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262]
#  [0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262]
#  [0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262]
#  [0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262 0.11398262]
#  [0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803]
#  [0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803]
#  [0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803]
#  [0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803]
#  [0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803 0.07023803]]
# c:\users\camp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:8: ComplexWarning: Casting complex values to real discards the imaginary part
#
# c:\users\camp\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:6: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
for A1 in Alist:
    print(nla.norm(shf.Pnomial(Ss[5]['sol'], A1), 'fro'))
# Out:
# 3.2219123019012342e-06
# 3.2190122909226843e-06
# 3.190012180118469e-06
# 2.9000110729096267e-06
# 1.7911932169933918e-16
# 2.9000110727291306e-05
# 0.0003190012180021334

# %%
nans = np.zeros((S.shape[0],1))
nans[:] = np.nan
for i in range(8):
    if i != 0:
        print(nla.norm(Ss[0]['sol'] - Ss[i]['sol'], 'fro'), nla.norm(Ss[8]['sol'] - Ss[i+8]['sol'], 'fro'))
        print('')
    print(np.concatenate((Ss[i]['sol'], nans ,Ss[i+8]['sol']), axis = 1))
    print('')
# Out:
# [[0.1733551  0.28258154 0.34595569 0.08595944 0.11211823        nan 0.17336242 0.28258962 0.34596429 0.08596315 0.11212051]
#  [0.26650921 0.19067981 0.30004615 0.17775085 0.06498398        nan 0.26651653 0.19068789 0.30005475 0.17775456 0.06498626]
#  [0.29475914 0.31843309 0.19921599 0.11781261 0.06974917        nan 0.29476646 0.31844117 0.19922459 0.11781632 0.06975146]
#  [0.26750171 0.26342209 0.32354547 0.08624754 0.0592532         nan 0.26750903 0.26343017 0.32355407 0.08625125 0.05925548]
#  [0.16199799 0.33074866 0.31869965 0.13589617 0.05262754        nan 0.16200531 0.33075674 0.31870825 0.13589988 0.05262982]]
#
# 8.976111343763139e-12 3.254721724306994e-07
#
# [[0.1733551  0.28258154 0.34595569 0.08595944 0.11211823        nan 0.17336235 0.28258954 0.34596421 0.08596312 0.11212049]
#  [0.26650921 0.19067981 0.30004615 0.17775085 0.06498398        nan 0.26651646 0.19068781 0.30005467 0.17775453 0.06498624]
#  [0.29475914 0.31843309 0.19921599 0.11781261 0.06974917        nan 0.29476639 0.31844109 0.1992245  0.11781629 0.06975143]
#  [0.26750171 0.26342209 0.32354547 0.08624754 0.0592532         nan 0.26750896 0.26343009 0.32355398 0.08625121 0.05925546]
#  [0.16199799 0.33074866 0.31869965 0.13589617 0.05262754        nan 0.16200523 0.33075666 0.31870816 0.13589984 0.0526298 ]]
#
# 1.378984148968562e-11 3.25477147675035e-06
#
# [[0.1733551  0.28258154 0.34595569 0.08595944 0.11211823        nan 0.17336169 0.28258881 0.34596343 0.08596278 0.11212029]
#  [0.26650921 0.19067981 0.30004615 0.17775085 0.06498398        nan 0.2665158  0.19068708 0.30005389 0.17775419 0.06498603]
#  [0.29475914 0.31843309 0.19921599 0.11781261 0.06974917        nan 0.29476573 0.31844036 0.19922373 0.11781595 0.06975123]
#  [0.26750171 0.26342209 0.32354547 0.08624754 0.0592532         nan 0.2675083  0.26342936 0.32355321 0.08625088 0.05925525]
#  [0.16199799 0.33074866 0.31869965 0.13589617 0.05262754        nan 0.16200458 0.33075594 0.31870739 0.1358995  0.0526296 ]]
#
# 6.521381381310265e-08 3.2482430551261485e-05
#
# [[0.17335509 0.28258152 0.34595568 0.08595944 0.11211822        nan 0.17335511 0.28258155 0.34595571 0.08595945 0.11211823]
#  [0.26650919 0.19067979 0.30004614 0.17775085 0.06498397        nan 0.26650922 0.19067982 0.30004617 0.17775086 0.06498398]
#  [0.29475913 0.31843307 0.19921597 0.1178126  0.06974917        nan 0.29475915 0.3184331  0.19921601 0.11781262 0.06974917]
#  [0.2675017  0.26342207 0.32354545 0.08624753 0.05925319        nan 0.26750173 0.2634221  0.32354548 0.08624755 0.0592532 ]
#  [0.16199797 0.33074865 0.31869963 0.13589616 0.05262753        nan 0.161998   0.33074868 0.31869967 0.13589617 0.05262754]]
#
# 0.000292930421149925 3.254781361172566e-05
#
# [[0.17328921 0.2825088  0.34587829 0.08592605 0.11209765        nan 0.1733551  0.28258154 0.34595569 0.08595944 0.11211823]
#  [0.26644332 0.19060707 0.29996875 0.17771746 0.0649634         nan 0.26650921 0.19067981 0.30004615 0.17775085 0.06498398]
#  [0.29469325 0.31836035 0.19913859 0.11777922 0.0697286         nan 0.29475914 0.31843309 0.19921599 0.11781261 0.06974917]
#  [0.26743582 0.26334935 0.32346806 0.08621415 0.05923262        nan 0.26750171 0.26342209 0.32354547 0.08624754 0.0592532 ]
#  [0.1619321  0.33067592 0.31862225 0.13586278 0.05260696        nan 0.16199799 0.33074866 0.31869965 0.13589617 0.05262754]]
#
# 0.003222234525274882 3.25478194744952e-05
#
# [[0.17263031 0.28178141 0.34510427 0.08559217 0.11189191        nan 0.1733551  0.28258154 0.34595569 0.08595944 0.11211823]
#  [0.26578442 0.18987968 0.29919473 0.17738357 0.06475765        nan 0.26650921 0.19067981 0.30004615 0.17775085 0.06498398]
#  [0.29403435 0.31763296 0.19836457 0.11744533 0.06952285        nan 0.29475914 0.31843309 0.19921599 0.11781261 0.06974917]
#  [0.26677693 0.26262196 0.32269404 0.08588026 0.05902687        nan 0.26750171 0.26342209 0.32354547 0.08624754 0.0592532 ]
#  [0.1612732  0.32994853 0.31784822 0.13552889 0.05240121        nan 0.16199799 0.33074866 0.31869965 0.13589617 0.05262754]]
#
# 0.03251527562146729 3.2547819564305735e-05
#
# [[0.16604136 0.27450749 0.33736406 0.08225327 0.10983442        nan 0.1733551  0.28258154 0.34595569 0.08595944 0.11211823]
#  [0.25919546 0.18260577 0.29145452 0.17404468 0.06270017        nan 0.26650921 0.19067981 0.30004615 0.17775085 0.06498398]
#  [0.2874454  0.31035905 0.19062436 0.11410644 0.06746536        nan 0.29475914 0.31843309 0.19921599 0.11781261 0.06974917]
#  [0.26018797 0.25534804 0.31495384 0.08254136 0.05696939        nan 0.26750171 0.26342209 0.32354547 0.08624754 0.0592532 ]
#  [0.15468424 0.32267462 0.31010802 0.13218999 0.05034373        nan 0.16199799 0.33074866 0.31869965 0.13589617 0.05262754]]
#
# 0.32544568658391904 3.254781955839892e-05
#
# [[0.10015178 0.20176837 0.25996199 0.04886429 0.08925956        nan 0.1733551  0.28258154 0.34595569 0.08595944 0.11211823]
#  [0.19330589 0.10986664 0.21405245 0.1406557  0.04212531        nan 0.26650921 0.19067981 0.30004615 0.17775085 0.06498398]
#  [0.22155582 0.23761992 0.11322229 0.08071746 0.04689051        nan 0.29475914 0.31843309 0.19921599 0.11781261 0.06974917]
#  [0.19429839 0.18260892 0.23755177 0.04915239 0.03639453        nan 0.26750171 0.26342209 0.32354547 0.08624754 0.0592532 ]
#  [0.08879467 0.2499355  0.23270595 0.09880101 0.02976887        nan 0.16199799 0.33074866 0.31869965 0.13589617 0.05262754]]

# %%
print(nla.norm(shf.Pnomial(np.ones(S.shape)/5, A), 'fro'))
# Out:
# 0.2875758192831401
