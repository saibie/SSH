# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

from jupyterthemes import jtplot
jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)
delt = .00000
m = 10
A = shf.MakeSingularA(m, 2, delta = delt)

# A = np.load('200121_Coefficients.npy')

# %%
for i in range(3):
    plt.matshow(A[i])

# %% [markdown]
# # $S$의 spectral radius 확인
# - 목적 : cyclic reduction 적용 가능 여부 확인
# - 웬만하면 안 되는 방향으로 ㅋㅋㅋㅋㅋㅋ

# %%
Ss = shf.NewtonPoly(A)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.set_title('Time = {:.10f}'.format(Ss['CalTime']))
ax.semilogy(Ss['errs'], '-or')

# %%
S2 = shf.CRPoly(A)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.set_title('Time = {:.10f}'.format(S2['CalTime']))
ax.semilogy(S2['errs'], '-or')
# Out:
# 022

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.semilogy(Ss['errs'], '-ob')
ax.semilogy(S2['errs'], '-or')

# %% [markdown]
# # 어? 생각보다 잘 되네;;;;
# ## 망함 ㅋㅋㅋㅋㅋㅋㅋㅋ

# %%
np.abs(nla.eig(Ss['sol'])[0])
# Out:
# array([0.99999988, 0.08957811, 0.01448346, 0.06803552, 0.06803552, 0.03322372, 0.03322372, 0.0474593 , 0.06246715, 0.06246715])

# %%
S = Ss['sol']

# %%
np.abs(nla.eig(nla.matrix_power(S, 1000000))[0])
# Out:
# array([0.00000000e+00, 8.87148853e-01, 3.06518293e-17, 2.02004181e-17, 2.02004181e-17, 1.48710904e-17, 8.12131301e-18, 8.12131301e-18, 5.10327904e-33, 5.10327904e-33])

# %%
Ss['sol']
# Out:
# array([[0.06253316, 0.07765483, 0.16496628, 0.08993204, 0.08724339, 0.07898222, 0.12153828, 0.11590286, 0.08614667, 0.11510015],
#        [0.07690669, 0.05072504, 0.10474311, 0.14660622, 0.07221282, 0.09213082, 0.1416871 , 0.14218848, 0.08255813, 0.09024147],
#        [0.08817695, 0.09377187, 0.09896345, 0.0908183 , 0.09012545, 0.11251468, 0.08820462, 0.17100593, 0.09078999, 0.07562863],
#        [0.13964813, 0.06458338, 0.14206379, 0.07096903, 0.06494244, 0.09045333, 0.06946779, 0.17340506, 0.11184809, 0.07261885],
#        [0.09063724, 0.09473268, 0.14287597, 0.12488426, 0.05264778, 0.1011124 , 0.09920199, 0.12690176, 0.10052242, 0.06648337],
#        [0.06639585, 0.07798606, 0.17949822, 0.10269985, 0.09107095, 0.06493167, 0.12619787, 0.1229316 , 0.08724898, 0.08103883],
#        [0.08362965, 0.05520201, 0.15124348, 0.11047902, 0.07285814, 0.1153552 , 0.06192593, 0.12937768, 0.09789045, 0.12203832],
# ...

# %%
S2['sol']
# Out:
# array([[0.06253316, 0.07765483, 0.16496628, 0.08993204, 0.08724339, 0.07898222, 0.12153828, 0.11590286, 0.08614667, 0.11510015],
#        [0.07690669, 0.05072504, 0.10474311, 0.14660622, 0.07221282, 0.09213082, 0.1416871 , 0.14218848, 0.08255813, 0.09024147],
#        [0.08817695, 0.09377187, 0.09896345, 0.0908183 , 0.09012545, 0.11251468, 0.08820462, 0.17100593, 0.09078999, 0.07562863],
#        [0.13964813, 0.06458338, 0.14206379, 0.07096903, 0.06494244, 0.09045333, 0.06946779, 0.17340506, 0.11184809, 0.07261885],
#        [0.09063724, 0.09473268, 0.14287597, 0.12488426, 0.05264778, 0.1011124 , 0.09920199, 0.12690176, 0.10052242, 0.06648337],
#        [0.06639585, 0.07798606, 0.17949822, 0.10269985, 0.09107095, 0.06493167, 0.12619787, 0.1229316 , 0.08724898, 0.08103883],
#        [0.08362965, 0.05520201, 0.15124348, 0.11047902, 0.07285814, 0.1153552 , 0.06192593, 0.12937768, 0.09789045, 0.12203832],
# ...

# %%
nla.norm(shf.Pnomial(Ss['sol'], A), 'fro')
# Out:
# 4.8204811881859445e-15

# %%
nla.norm(shf.Pnomial(S2['sol'], A), 'fro')
# Out:
# 4.8243085111685025e-15

# %%
plt.semilogy([nla.norm(Ss['Xs'][i] - S2['Xs'][i], 'fro') for i in range(len(Ss['Xs']))], '-o')

# %%
nla.norm(Ss['sol'] - S2['sol'], 'fro')
# Out:
# 8.797116518357802e-11
