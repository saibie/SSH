# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

from jupyterthemes import jtplot
jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)
delt = .000004
m = 30
A = shf.MakeGenSingA(m, 4, delta = delt)

# A = np.load('200121_Coefficients.npy')

# %%
Ss = [None] * 7
MethodVariation = ['Pure', 'Kelley', 'Modified', 'ELSearch', 'MLSearch2', 'BLSearch', 'BLSInner']
LineIter = 5
for i in range(7):
    Ss[i] = shf.NewtonPoly(A, cls = MethodVariation[i], LS_iter = LineIter)

# %%
fig = plt.figure(figsize=(20, 10))
ax = [None] * 7
for i in range(7):
    ax[i] = fig.add_subplot(2, 4, i+1)
    ax[i].set_title('Time = {:.10f}'.format(Ss[i]['CalTime']))
    if i != 0:
        ax[i].semilogy(Ss[0]['errs'], '-or')
    ax[i].semilogy(Ss[i]['errs'], '-ob')
    if i != 0:
        ax[i].set_ylim(ax[0].get_ylim())
#         ax[i].set_xlim(ax[0].get_xlim())

# %%
n = A.shape[0]-1
pt = np.zeros(2*n + 1)
X0, H0 = Ss[0]['Xs'][10], Ss[0]['Hs'][10]
for t in range(2*n + 1):
    pt[t] = shf.CoeffiLSearch(A, X0, -H0, t)
pt = np.flip(pt)
# pt = pt/np.min(np.abs(pt))
print(pt)
# Out:
# [ 6.00813697e-32  4.25913071e-27  1.13215781e-22  1.33731895e-18  5.91934269e-15 -4.74087065e-14  1.42275194e-13 -1.89722252e-13  9.48511154e-14]

# %%
T = np.arange(0, 2*n + 1)
PT = [nla.norm(shf.Pnomial(X0 - t*H0, A), 'fro')**2 for t in T]
PT = np.asarray(PT)

ptA = np.zeros((2*n+1, 2*n+1))
for i in range(2*n+1):
    ptA[:,-i-1] = T**i
pt2 = nla.inv(ptA) @ PT
print(pt2)
# Out:
# [-3.99069941e-27  1.27083914e-25  1.11665331e-22  1.33732931e-18  5.91934265e-15 -4.74087064e-14  1.42275194e-13 -1.89722272e-13  9.48611359e-14]

# %%
print(PT)
print(pt)
print(pt2)
# Out:
# [9.48611359e-14 5.92603186e-15 1.42125818e-21 5.92780145e-15 9.49395465e-14 4.80811391e-13 1.52002629e-12 3.71193486e-12 7.69891627e-12]
# [ 6.00813697e-32  4.25913071e-27  1.13215781e-22  1.33731895e-18  5.91934269e-15 -4.74087065e-14  1.42275194e-13 -1.89722252e-13  9.48511154e-14]
# [-3.99069941e-27  1.27083914e-25  1.11665331e-22  1.33732931e-18  5.91934265e-15 -4.74087064e-14  1.42275194e-13 -1.89722272e-13  9.48611359e-14]

# %%
rt = np.roots(pt)
rt2 = np.roots(pt2)

fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.plot(np.real(rt), np.imag(rt), 'o')
ax1.set_xlim([-1, 3])
ax1.set_ylim([-2, 2])
ax2.plot(np.real(rt2), np.imag(rt2), 'o')
ax2.set_xlim([-1, 3])
ax2.set_ylim([-2, 2])
# Out:
# (-2, 2)
