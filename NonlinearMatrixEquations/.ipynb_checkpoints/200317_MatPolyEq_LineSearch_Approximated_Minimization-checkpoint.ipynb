# %%
# %matplotlib inline

import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

from jupyterthemes import jtplot
jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)
delt = .000004
m = 30
A = shf.MakeGenSingA(m, 6, delta = delt)

# A = np.load('200121_Coefficients.npy')

# %%
Ss = [None] * 7
MethodVariation = ['Pure', 'Kelley', 'Modified', 'ELSearch', 'MLSearch2', 'BLSearch', 'BLSInner']
LineIter = 5
for i in range(7):
    Ss[i] = shf.NewtonPoly(A, cls = MethodVariation[i], LS_iter = LineIter)

# %%
fig = plt.figure(figsize=(20, 10))
ax = [None] * 7
for i in range(7):
    ax[i] = fig.add_subplot(2, 4, i+1)
    ax[i].set_title('{} : Time = {:.10f}'.format(MethodVariation[i], Ss[i]['CalTime']))
    if i != 0:
        ax[i].semilogy(Ss[0]['errs'], '-or')
    ax[i].semilogy(Ss[i]['errs'], '-ob')
    if i != 0:
        ax[i].set_ylim(ax[0].get_ylim())
#         ax[i].set_xlim(ax[0].get_xlim())

# %%
n = A.shape[0]-1
pt = np.zeros(2*n + 1)
X0, H0 = Ss[0]['Xs'][10], Ss[0]['Hs'][10]
for t in range(2*n + 1):
    pt[t] = shf.CoeffiLSearch(A, X0, -H0, t)
pt = np.flip(pt)
# pt = pt/np.min(np.abs(pt))
print(pt)
# Out:
# [ 6.03832644e-32  4.28053184e-27  1.13784664e-22  1.34403866e-18  5.94908599e-15 -4.76469240e-14  1.42990093e-13 -1.90675598e-13  9.54178922e-14]

# %%
T = np.arange(0, 2*n + 1)
PT = [nla.norm(shf.Pnomial(X0 - t*H0, A), 'fro')**2 for t in T]
PT = np.asarray(PT)

ptA = np.zeros((2*n+1, 2*n+1))
for i in range(2*n+1):
    ptA[:,-i-1] = T**i
pt2 = nla.inv(ptA) @ PT
print(pt2)
# Out:
# [-9.99984735e-27  2.93201455e-25  1.10411964e-22  1.34405921e-18  5.94908592e-15 -4.76469239e-14  1.42990093e-13 -1.90675581e-13  9.53377908e-14]

# %%
print(PT)
print(pt)
print(pt2)
# Out:
# [9.53377908e-14 5.95580878e-15 1.42840246e-21 5.95758724e-15 9.54165952e-14 4.83227354e-13 1.52766407e-12 3.73058645e-12 7.73760151e-12]
# [ 6.03832644e-32  4.28053184e-27  1.13784664e-22  1.34403866e-18  5.94908599e-15 -4.76469240e-14  1.42990093e-13 -1.90675598e-13  9.54178922e-14]
# [-9.99984735e-27  2.93201455e-25  1.10411964e-22  1.34405921e-18  5.94908592e-15 -4.76469239e-14  1.42990093e-13 -1.90675581e-13  9.53377908e-14]

# %%
rt = np.roots(pt)
rt2 = np.roots(pt2)

fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.plot(np.real(rt), np.imag(rt), 'o')
ax1.set_xlim([-1, 3])
ax1.set_ylim([-2, 2])
ax2.plot(np.real(rt2), np.imag(rt2), 'o')
ax2.set_xlim([-1, 3])
ax2.set_ylim([-2, 2])
# Out:
# (-2, 2)
