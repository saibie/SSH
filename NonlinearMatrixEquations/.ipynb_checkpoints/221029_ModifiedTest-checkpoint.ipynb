# %%
import numpy as np
from numpy import linalg as nla
import scipy as sp
from scipy import linalg as sla
import SHFunctions as shf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pprint import pprint
from time import time
import os

# from jupyterthemes import jtplot
# jtplot.style(theme='solarizedl')

from IPython.core.display import display, HTML
np.set_printoptions(linewidth = 270)

# %%
# A, S = shf.MakeOneSingA(5, 8, delta = .00000)
# S = np.real(S)
delt = .01
m = 10
n = 6
A = shf.MakeGenSingA(m, n, delta = delt)

# A = np.load('200121_Coefficients.npy')

# %%
Ss = shf.NewtonPoly(A)

# %%
S0s = shf.NewtonPolyModified(A)

# %%
# X = np.random.random((10, 10))
X = np.zeros((10, 10))

# %%
time0 = time()
P_X = np.zeros((m**2, m**2))
for k in range(1,n+1):
    for l in range(k):
        P_X = P_X + np.kron(nla.matrix_power(X.transpose(),k-l-1), A[k,:,:] @ nla.matrix_power(X, l))
time0 = time() - time0
print(time0)
# Out:
# 0.0029039382934570312

# %%
time1 = time()
P_X1 = shf.Deriv_P(X, A)
time1 = time() - time1
print(time1)
# Out:
# 0.0019526481628417969

# %%
nla.norm(P_X - P_X1)
# Out:
# 0.0

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.set_title('Time = {:.10f}, Time = {:.10f}'.format(Ss['CalTime'], S0s['CalTime']))
ax.semilogy(Ss['errs'], '-or')
ax.semilogy(S0s['errs'], '-ob')

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1)
ax.set_title('Time = {:.10f}, Time = {:.10f}'.format(Ss['CalTime'], S0s['CalTime']))
ax.semilogy(np.add.accumulate(Ss['IterTime']), Ss['errs'][1:], '-or')
ax.semilogy(np.add.accumulate(S0s['IterTime']), S0s['errs'][1:], '-ob')

# %%
S = Ss['sol']
s = np.reshape(S, (np.prod(S.shape),), order='F')
P_S = Ss['P_Xs'][-1]
d, X = nla.eig(P_S)
imin = np.argmin(np.abs(d))
e = d[imin]
x = X[:,imin]
a = nla.inv(X) @ s
Pns = a[imin] * x

# %%
xx = np.real(np.reshape(np.sign(x[0])*x, S.shape, order = 'F'))
print('---------xx---------')
print(xx)
X0 = S - xx
print('---------X0---------')
print(X0)

P_X0 = np.zeros(P_S.shape)
for k in range(1, A.shape[0]):
    for l in range(k):
        P_X0 = P_X0 + np.kron(nla.matrix_power(X0.transpose(),k-l-1), A[k,:,:] @ nla.matrix_power(X0, l))
vP = np.reshape(shf.Pnomial(X0, A), m**2, 'F') # Reshape는 반드시 Fortran 방식으로
h = nla.solve(P_X0, vP)
H = np.reshape(h, S.shape, order = 'F')
X1 = X0 - H
x1s = np.reshape(S - X1, (np.prod(S.shape),), order='F')
x0s = np.reshape(S - X0, (np.prod(S.shape),), order='F')
a = nla.inv(X) @ x1s
a0 = nla.inv(X) @ x0s
Pnx1s = a[imin] * x
Pnx0s = a0[imin] * x
print('---------X1---------')
print(X1)
print('-------S - X1-------')
print(S - X1)
print('-----PN(S - X1)-----')
print(np.real(np.reshape(Pnx1s, S.shape, order='F')))
print('-------(S - X1) - PN(S - X1)-----')
print(S - X1 - np.real(np.reshape(Pnx1s, S.shape, order='F')))
print('-------||(S - X1) - PN(S - X1)||-----')
print(nla.norm(Pnx1s - x1s))
print('-------||(S - X0) - PN(S - X0)||-----')
print(nla.norm(Pnx0s - x0s))
# Out:
# ---------xx---------
# [[0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]
#  [0.09775755 0.1066359  0.09833813 0.07956959 0.10833711 0.09053799 0.09296818 0.07977429 0.12286744 0.1141624 ]]
# ---------X0---------
# [[-0.0642816  -0.01243554  0.09634943 -0.01635413  0.00905339 -0.04129464 -0.00608353 -0.0028773  -0.02017237  0.06710048]
#  [ 0.07044036 -0.07010947  0.06872043 -0.03244778 -0.05466574 -0.0516907   0.06766499 -0.01456027  0.05094931 -0.02529694]
#  [ 0.05802943  0.04100982 -0.06453961  0.07147028  0.01757106 -0.03650154 -0.03522444 -0.01980108 -0.00237966 -0.02063009]
#  [-0.05925329  0.01442586  0.01575032 -0.05219154  0.00330215 -0.03876708  0.07890855 -0.00902194  0.03631129  0.01953985]
#  [-0.03090844  0.07139913 -0.05517016 -0.03525858 -0.07105123  0.09394481 -0.04062335  0.07780575 -0.06819638  0.06706263]
#  [-0.03127484  0.04409247  0.00331051  0.0513238   0.04476065 -0.05949113  0.07649468 -0.02653461 -0.03486357 -0.05881378]
#  [-0.02371038 -0.05681215  0.00548818  0.06091326  0.00401197  0.00540939 -0.06065276  0.04913109  0.05555178 -0.03032621]
#  [ 0.00792512 -0.01341476 -0.01215276  0.022443    0.03174885  0.00742598 -0.04191512 -0.05244816  0.06048385 -0.00109181]
#  [ 0.01180483  0.00221804  0.0100125  -0.03099491  0.0114613   0.08347808 -0.01675525 -0.03979517 -0.08070112  0.05827589]
#  [ 0.04347119 -0.0103058  -0.05134568 -0.0137711   0.02855689  0.00783793 -0.00071807  0.03237806  0.04783226 -0.0749315 ]]
# ---------X1---------
# [[0.00067346 0.05841874 0.16169026 0.03651593 0.08103805 0.01886338 0.05568923 0.05012877 0.06146698 0.14295575]
#  [0.13539542 0.00074481 0.13406126 0.02042228 0.01731891 0.00846732 0.12943775 0.0384458  0.13258866 0.05055833]
#  [0.1229845  0.1118641  0.00080122 0.12434034 0.08955572 0.02365648 0.02654832 0.03320499 0.07925969 0.05522518]
#  [0.00570177 0.08528015 0.08109115 0.00067852 0.07528681 0.02139094 0.14068131 0.04398413 0.11795064 0.09539512]
#  [0.03404662 0.14225341 0.01017067 0.01761148 0.00093343 0.15410283 0.02114941 0.13081182 0.01344296 0.1429179 ]
#  [0.03368022 0.11494675 0.06865134 0.10419386 0.11674531 0.00066689 0.13826744 0.02647146 0.04677578 0.0170415 ]
#  [0.04124468 0.01404214 0.07082901 0.11378332 0.07599663 0.06556741 0.00112    0.10213716 0.13719112 0.04552906]
#  [0.07288018 0.05743952 0.05318807 0.07531306 0.10373351 0.06758399 0.01985764 0.00055791 0.14212319 0.07476346]
#  [0.07675989 0.07307232 0.07535333 0.02187515 0.08344596 0.1436361  0.04501751 0.0132109  0.00093823 0.13413116]
#  [0.10842625 0.06054848 0.01399515 0.03909896 0.10054155 0.06799595 0.06105469 0.08538413 0.1294716  0.00092378]]
# -------S - X1-------
# [[0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]]
# -----PN(S - X1)-----
# [[0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]
#  [0.03280249 0.03578161 0.0329973  0.02669953 0.03635246 0.03037997 0.03119542 0.02676822 0.0412281  0.03830713]]
# -------(S - X1) - PN(S - X1)-----
# [[-6.93889390e-18 -2.77555756e-17 -6.93889390e-18 -1.04083409e-17 -1.04083409e-16 -2.77555756e-17 -1.00613962e-16 -3.12250226e-17 -3.46944695e-17 -1.38777878e-17]
#  [-6.93889390e-18  4.16333634e-17 -6.93889390e-17 -3.81639165e-17 -1.17961196e-16 -5.55111512e-17 -6.93889390e-18 -3.46944695e-17  1.38777878e-17 -4.16333634e-17]
#  [ 0.00000000e+00 -4.16333634e-17  6.24500451e-17 -3.46944695e-18 -4.85722573e-17 -3.46944695e-17 -5.55111512e-17 -8.32667268e-17 -2.08166817e-17 -1.38777878e-17]
#  [-2.08166817e-17 -6.24500451e-17 -9.71445147e-17 -4.51028104e-17 -6.24500451e-17 -5.55111512e-17 -3.12250226e-17 -1.73472348e-17 -1.11022302e-16 -3.46944695e-17]
#  [-5.55111512e-17 -4.16333634e-17 -4.16333634e-17 -1.04083409e-17 -1.11022302e-16  6.93889390e-18 -4.85722573e-17  4.51028104e-17  2.08166817e-17  2.77555756e-17]
#  [-2.77555756e-17 -1.38777878e-17 -4.16333634e-17 -7.63278329e-17 -1.31838984e-16 -3.12250226e-17 -6.93889390e-18  0.00000000e+00 -4.85722573e-17  0.00000000e+00]
#  [-7.63278329e-17 -9.71445147e-17  6.93889390e-18 -9.36750677e-17 -7.63278329e-17 -6.24500451e-17 -6.24500451e-17 -2.08166817e-17 -1.38777878e-17 -7.63278329e-17]
#  [ 2.77555756e-17 -1.38777878e-17  0.00000000e+00 -2.42861287e-17 -9.02056208e-17  2.77555756e-17 -7.97972799e-17 -1.73472348e-17  2.77555756e-17  2.08166817e-17]
#  [-6.93889390e-17 -4.16333634e-17  2.77555756e-17  1.73472348e-17 -2.08166817e-17 -2.77555756e-17 -2.77555756e-17 -3.12250226e-17 -3.46944695e-17 -2.77555756e-17]
#  [-4.85722573e-17 -4.85722573e-17 -5.55111512e-17 -9.36750677e-17 -6.24500451e-17 -5.55111512e-17 -5.89805982e-17 -2.08166817e-17 -3.46944695e-17 -1.17961196e-16]]
# -------||(S - X1) - PN(S - X1)||-----
# 5.319199775086973e-16
# -------||(S - X0) - PN(S - X0)||-----
# 8.866951814370875e-16

# %% [markdown]
# ### $\tilde{X}_{i}$가 $\mathcal{N}$에 들어가면, $\tilde{X}_{i+1}$도 $\mathcal{N}$에 들어가는 것으로 추정됨
