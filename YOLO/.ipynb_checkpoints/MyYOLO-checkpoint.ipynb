# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import json
from pprint import pprint

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
np.set_printoptions(threshold = None, linewidth = 200)

print(tf.__version__)
print(keras.__version__)
# Out:
# <style>.container { width:95% !important; }</style>
# 1.13.1
# 2.2.4-tf

# %% [markdown]
# ## Eager 모드 활성화

# %%
tf.enable_eager_execution()

# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17722966636837489516
# ]

# %% [markdown]
# ## Hyper parameters

# %%
learning_rate = 0.001
training_epochs = 15
batch_size = 100

# tf.set_random_seed(777)

# %% [markdown]
# ## Creating a Checkpoint Directory

# %%
cur_dir = os.getcwd()
ckpt_dir_name = 'checkpoints'
model_dir_name = 'yolo_cnn_seq'

checkpoint_dir = os.path.join(cur_dir, ckpt_dir_name, model_dir_name)
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_prefix = os.path.join(checkpoint_dir, model_dir_name)

# %% [markdown]
# ## Data

# %%
# mnist = keras.datasets.mnist
class_names = ['Car']

xwidth = 1280
xheight = 720

boxfile = open("highway-cctv-footage-images/ground_truth_boxes/labelbox.json", "r")#, encoding = "UTF-8")
data = json.load(boxfile)
# boxes = [box[:-1] for box in boxes]
for datum in data:
#     pprint(boxes[i]['External ID'])
    pprint(datum)
# Out:
# {'Agreement': None,
#  'Created At': '2019-01-25T19:08:33.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn31700anv2e2kqcyb',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_0.jpg',
#  'ID': 'cjrcf62w2y9d60896156vonw5',
#  'Label': {'Car': [{'geometry': [{'x': 887, 'y': 447},
#                                  {'x': 887, 'y': 629},
#                                  {'x': 1074, 'y': 629},
#                                  {'x': 1074, 'y': 447}]},
#                    {'geometry': [{'x': 142, 'y': 54},
#                                  {'x': 142, 'y': 85},
#                                  {'x': 200, 'y': 85},
#                                  {'x': 200, 'y': 54}]},
#                    {'geometry': [{'x': 319, 'y': 32},
#                                  {'x': 319, 'y': 65},
#                                  {'x': 362, 'y': 65},
#                                  {'x': 362, 'y': 32}]},
#                    {'geometry': [{'x': 286, 'y': 13},
#                                  {'x': 286, 'y': 38},
#                                  {'x': 326, 'y': 38},
#                                  {'x': 326, 'y': 13}]},
#                    {'geometry': [{'x': 578, 'y': 69},
#                                  {'x': 578, 'y': 98},
#                                  {'x': 616, 'y': 98},
#                                  {'x': 616, 'y': 69}]},
#                    {'geometry': [{'x': 783, 'y': 68},
#                                  {'x': 783, 'y': 96},
#                                  {'x': 822, 'y': 96},
#                                  {'x': 822, 'y': 68}]},
#                    {'geometry': [{'x': 747, 'y': 37},
#                                  {'x': 747, 'y': 68},
#                                  {'x': 780, 'y': 68},
#                                  {'x': 780, 'y': 37}]},
#                    {'geometry': [{'x': 751, 'y': 22},
#                                  {'x': 751, 'y': 44},
#                                  {'x': 776, 'y': 44},
#                                  {'x': 776, 'y': 22}]},
#                    {'geometry': [{'x': 0, 'y': 109},
#                                  {'x': 0, 'y': 169},
#                                  {'x': 44, 'y': 169},
#                                  {'x': 44, 'y': 109}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_0.jpg?alt=media&token=872f42d5-262e-4ded-9451-8d56434e1f70',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 153.396,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcf62w2y9d60896156vonw5'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:09:55.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn31740anv7g7lcqje',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_1.jpg',
#  'ID': 'cjrcf7ubuyb4p08967nzz4fg1',
#  'Label': {'Car': [{'geometry': [{'x': 637, 'y': 359},
#                                  {'x': 637, 'y': 504},
#                                  {'x': 756, 'y': 504},
#                                  {'x': 756, 'y': 359}]},
#                    {'geometry': [{'x': 815, 'y': 284},
#                                  {'x': 815, 'y': 372},
#                                  {'x': 922, 'y': 372},
#                                  {'x': 922, 'y': 284}]},
#                    {'geometry': [{'x': 775, 'y': 50},
#                                  {'x': 775, 'y': 76},
#                                  {'x': 807, 'y': 76},
#                                  {'x': 807, 'y': 50}]},
#                    {'geometry': [{'x': 742, 'y': 26},
#                                  {'x': 742, 'y': 54},
#                                  {'x': 773, 'y': 54},
#                                  {'x': 773, 'y': 26}]},
#                    {'geometry': [{'x': 591, 'y': 48},
#                                  {'x': 591, 'y': 70},
#                                  {'x': 621, 'y': 70},
#                                  {'x': 621, 'y': 48}]},
#                    {'geometry': [{'x': 435, 'y': 0},
#                                  {'x': 435, 'y': 16},
#                                  {'x': 460, 'y': 16},
#                                  {'x': 460, 'y': 0}]},
#                    {'geometry': [{'x': 259, 'y': 52},
#                                  {'x': 259, 'y': 88},
#                                  {'x': 311, 'y': 88},
#                                  {'x': 311, 'y': 52}]},
#                    {'geometry': [{'x': 250, 'y': 21},
#                                  {'x': 250, 'y': 49},
#                                  {'x': 296, 'y': 49},
#                                  {'x': 296, 'y': 21}]},
#                    {'geometry': [{'x': 66, 'y': 72},
#                                  {'x': 66, 'y': 108},
#                                  {'x': 137, 'y': 108},
#                                  {'x': 137, 'y': 72}]},
#                    {'geometry': [{'x': 746, 'y': 13},
#                                  {'x': 746, 'y': 27},
#                                  {'x': 767, 'y': 27},
#                                  {'x': 767, 'y': 13}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_1.jpg?alt=media&token=1d6adab4-67f1-48e2-b578-c5ee0a02fda3',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 80.974,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcf7ubuyb4p08967nzz4fg1'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:10:45.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn31780anvghulcnc2',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_2.jpg',
#  'ID': 'cjrcf8wk4ybye0896ezvi4slp',
#  'Label': {'Car': [{'geometry': [{'x': 645, 'y': 235},
#                                  {'x': 645, 'y': 315},
#                                  {'x': 722, 'y': 315},
#                                  {'x': 722, 'y': 235}]},
#                    {'geometry': [{'x': 785, 'y': 193},
#                                  {'x': 785, 'y': 254},
#                                  {'x': 857, 'y': 254},
#                                  {'x': 857, 'y': 193}]},
#                    {'geometry': [{'x': 766, 'y': 38},
#                                  {'x': 766, 'y': 60},
#                                  {'x': 795, 'y': 60},
#                                  {'x': 795, 'y': 38}]},
#                    {'geometry': [{'x': 739, 'y': 17},
#                                  {'x': 739, 'y': 42},
#                                  {'x': 765, 'y': 42},
#                                  {'x': 765, 'y': 17}]},
#                    {'geometry': [{'x': 740, 'y': 7},
#                                  {'x': 740, 'y': 22},
#                                  {'x': 760, 'y': 22},
#                                  {'x': 760, 'y': 7}]},
#                    {'geometry': [{'x': 600, 'y': 30},
#                                  {'x': 600, 'y': 51},
#                                  {'x': 625, 'y': 51},
#                                  {'x': 625, 'y': 30}]},
#                    {'geometry': [{'x': 412, 'y': 4},
#                                  {'x': 412, 'y': 26},
#                                  {'x': 439, 'y': 26},
#                                  {'x': 439, 'y': 4}]},
#                    {'geometry': [{'x': 175, 'y': 77},
#                                  {'x': 175, 'y': 123},
#                                  {'x': 242, 'y': 123},
#                                  {'x': 242, 'y': 77}]},
#                    {'geometry': [{'x': 206, 'y': 31},
#                                  {'x': 206, 'y': 63},
#                                  {'x': 259, 'y': 63},
#                                  {'x': 259, 'y': 31}]},
#                    {'geometry': [{'x': 0, 'y': 95},
#                                  {'x': 0, 'y': 139},
#                                  {'x': 53, 'y': 139},
#                                  {'x': 53, 'y': 95}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_2.jpg?alt=media&token=f4146283-0175-4e51-b10b-3cb246c7791b',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 48.507,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcf8wk4ybye0896ezvi4slp'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:11:34.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn317c0anvncjl8wmb',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_3.jpg',
#  'ID': 'cjrcf9yooycyr08965nyfsp7v',
#  'Label': {'Car': [{'geometry': [{'x': 350, 'y': 450},
#                                  {'x': 350, 'y': 661},
#                                  {'x': 536, 'y': 661},
#                                  {'x': 536, 'y': 450}]},
#                    {'geometry': [{'x': 647, 'y': 163},
#                                  {'x': 647, 'y': 220},
#                                  {'x': 707, 'y': 220},
#                                  {'x': 707, 'y': 163}]},
#                    {'geometry': [{'x': 764, 'y': 140},
#                                  {'x': 764, 'y': 189},
#                                  {'x': 819, 'y': 189},
#                                  {'x': 819, 'y': 140}]},
#                    {'geometry': [{'x': 758, 'y': 28},
#                                  {'x': 758, 'y': 48},
#                                  {'x': 785, 'y': 48},
#                                  {'x': 785, 'y': 28}]},
#                    {'geometry': [{'x': 734, 'y': 10},
#                                  {'x': 734, 'y': 32},
#                                  {'x': 759, 'y': 32},
#                                  {'x': 759, 'y': 10}]},
#                    {'geometry': [{'x': 734, 'y': 0},
#                                  {'x': 734, 'y': 14},
#                                  {'x': 752, 'y': 14},
#                                  {'x': 752, 'y': 0}]},
#                    {'geometry': [{'x': 606, 'y': 19},
#                                  {'x': 606, 'y': 37},
#                                  {'x': 629, 'y': 37},
#                                  {'x': 629, 'y': 19}]},
#                    {'geometry': [{'x': 382, 'y': 14},
#                                  {'x': 382, 'y': 41},
#                                  {'x': 414, 'y': 41},
#                                  {'x': 414, 'y': 14}]},
#                    {'geometry': [{'x': 152, 'y': 46},
#                                  {'x': 152, 'y': 79},
#                                  {'x': 213, 'y': 79},
#                                  {'x': 213, 'y': 46}]},
#                    {'geometry': [{'x': 47, 'y': 114},
#                                  {'x': 47, 'y': 176},
#                                  {'x': 141, 'y': 176},
#                                  {'x': 141, 'y': 114}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_3.jpg?alt=media&token=4a0c7bd6-d085-45f4-bb6d-1571c3d66fa0',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 47.25,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcf9yooycyr08965nyfsp7v'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:12:28.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn317g0anvt3ugofp6',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_4.jpg',
#  'ID': 'cjrcfb45swpsu0797yeyve8zd',
#  'Label': {'Car': [{'geometry': [{'x': 638, 'y': 433},
#                                  {'x': 638, 'y': 596},
#                                  {'x': 761, 'y': 596},
#                                  {'x': 761, 'y': 433}]},
#                    {'geometry': [{'x': 480, 'y': 266},
#                                  {'x': 480, 'y': 353},
#                                  {'x': 579, 'y': 353},
#                                  {'x': 579, 'y': 266}]},
#                    {'geometry': [{'x': 650, 'y': 118},
#                                  {'x': 650, 'y': 162},
#                                  {'x': 698, 'y': 162},
#                                  {'x': 698, 'y': 118}]},
#                    {'geometry': [{'x': 750, 'y': 104},
#                                  {'x': 750, 'y': 140},
#                                  {'x': 795, 'y': 140},
#                                  {'x': 795, 'y': 104}]},
#                    {'geometry': [{'x': 751, 'y': 12},
#                                  {'x': 751, 'y': 36},
#                                  {'x': 775, 'y': 36},
#                                  {'x': 775, 'y': 12}]},
#                    {'geometry': [{'x': 728, 'y': 0},
#                                  {'x': 728, 'y': 24},
#                                  {'x': 754, 'y': 24},
#                                  {'x': 754, 'y': 0}]},
#                    {'geometry': [{'x': 612, 'y': 8},
#                                  {'x': 612, 'y': 23},
#                                  {'x': 632, 'y': 23},
#                                  {'x': 632, 'y': 8}]},
#                    {'geometry': [{'x': 342, 'y': 27},
#                                  {'x': 342, 'y': 56},
#                                  {'x': 380, 'y': 56},
#                                  {'x': 380, 'y': 27}]},
#                    {'geometry': [{'x': 82, 'y': 59},
#                                  {'x': 82, 'y': 99},
#                                  {'x': 157, 'y': 99},
#                                  {'x': 157, 'y': 59}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_4.jpg?alt=media&token=de75d700-4ba3-4138-acb0-eb59b66fa594',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 52.646,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcfb45swpsu0797yeyve8zd'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:13:25.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn317k0anvpa2t6web',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_5.jpg',
#  'ID': 'cjrcfcchiyfo60896ti7tvzo6',
#  'Label': {'Car': [{'geometry': [{'x': 859, 'y': 384},
#                                  {'x': 859, 'y': 543},
#                                  {'x': 1021, 'y': 543},
#                                  {'x': 1021, 'y': 384}]},
#                    {'geometry': [{'x': 643, 'y': 275},
#                                  {'x': 643, 'y': 364},
#                                  {'x': 728, 'y': 364},
#                                  {'x': 728, 'y': 275}]},
#                    {'geometry': [{'x': 535, 'y': 173},
#                                  {'x': 535, 'y': 229},
#                                  {'x': 602, 'y': 229},
#                                  {'x': 602, 'y': 173}]},
#                    {'geometry': [{'x': 117, 'y': 379},
#                                  {'x': 117, 'y': 549},
#                                  {'x': 344, 'y': 549},
#                                  {'x': 344, 'y': 379}]},
#                    {'geometry': [{'x': 649, 'y': 86},
#                                  {'x': 649, 'y': 122},
#                                  {'x': 690, 'y': 122},
#                                  {'x': 690, 'y': 86}]},
#                    {'geometry': [{'x': 741, 'y': 79},
#                                  {'x': 741, 'y': 111},
#                                  {'x': 780, 'y': 111},
#                                  {'x': 780, 'y': 79}]},
#                    {'geometry': [{'x': 746, 'y': 6},
#                                  {'x': 746, 'y': 27},
#                                  {'x': 767, 'y': 27},
#                                  {'x': 767, 'y': 6}]},
#                    {'geometry': [{'x': 724, 'y': 16},
#                                  {'x': 724, 'y': 0},
#                                  {'x': 747, 'y': 0},
#                                  {'x': 747, 'y': 16}]},
#                    {'geometry': [{'x': 615, 'y': 2},
#                                  {'x': 615, 'y': 16},
#                                  {'x': 634, 'y': 16},
#                                  {'x': 634, 'y': 2}]},
#                    {'geometry': [{'x': 483, 'y': 12},
#                                  {'x': 483, 'y': 0},
#                                  {'x': 506, 'y': 0},
#                                  {'x': 506, 'y': 12}]},
#                    {'geometry': [{'x': 287, 'y': 45},
#                                  {'x': 287, 'y': 81},
#                                  {'x': 335, 'y': 81},
#                                  {'x': 335, 'y': 45}]},
#                    {'geometry': [{'x': 0, 'y': 81},
#                                  {'x': 0, 'y': 123},
#                                  {'x': 84, 'y': 123},
#                                  {'x': 84, 'y': 81}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_5.jpg?alt=media&token=c16aea5c-339f-4efd-8d13-29d14e44292a',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 56.305,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcfcchiyfo60896ti7tvzo6'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:14:23.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn317o0anv2gyyncvt',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_6.jpg',
#  'ID': 'cjrcfdkq4ygyv0896vv5dm7d0',
#  'Label': {'Car': [{'geometry': [{'x': 800, 'y': 241},
#                                  {'x': 800, 'y': 323},
#                                  {'x': 895, 'y': 323},
#                                  {'x': 895, 'y': 241}]},
#                    {'geometry': [{'x': 651, 'y': 190},
#                                  {'x': 651, 'y': 245},
#                                  {'x': 712, 'y': 245},
#                                  {'x': 712, 'y': 190}]},
#                    {'geometry': [{'x': 565, 'y': 118},
#                                  {'x': 565, 'y': 159},
#                                  {'x': 616, 'y': 159},
#                                  {'x': 616, 'y': 118}]},
#                    {'geometry': [{'x': 651, 'y': 67},
#                                  {'x': 651, 'y': 92},
#                                  {'x': 686, 'y': 92},
#                                  {'x': 686, 'y': 67}]},
#                    {'geometry': [{'x': 735, 'y': 60},
#                                  {'x': 735, 'y': 87},
#                                  {'x': 768, 'y': 87},
#                                  {'x': 768, 'y': 60}]},
#                    {'geometry': [{'x': 740, 'y': 4},
#                                  {'x': 740, 'y': 20},
#                                  {'x': 761, 'y': 20},
#                                  {'x': 761, 'y': 4}]},
#                    {'geometry': [{'x': 721, 'y': 11},
#                                  {'x': 721, 'y': 0},
#                                  {'x': 742, 'y': 0},
#                                  {'x': 742, 'y': 11}]},
#                    {'geometry': [{'x': 463, 'y': 23},
#                                  {'x': 463, 'y': 2},
#                                  {'x': 491, 'y': 2},
#                                  {'x': 491, 'y': 23}]},
#                    {'geometry': [{'x': 208, 'y': 69},
#                                  {'x': 208, 'y': 112},
#                                  {'x': 270, 'y': 112},
#                                  {'x': 270, 'y': 69}]},
#                    {'geometry': [{'x': 346, 'y': 207},
#                                  {'x': 346, 'y': 300},
#                                  {'x': 462, 'y': 300},
#                                  {'x': 462, 'y': 207}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_6.jpg?alt=media&token=1f9140eb-faa7-4ea1-8f3c-c51df0f7f42d',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 56.323,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcfdkq4ygyv0896vv5dm7d0'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:16:02.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqn317s0anv5j5ftbcs',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_7.jpg',
#  'ID': 'cjrcffp9xwu1a0797up2cio7p',
#  'Label': {'Car': [{'geometry': [{'x': 909, 'y': 426},
#                                  {'x': 909, 'y': 584},
#                                  {'x': 1079, 'y': 584},
#                                  {'x': 1079, 'y': 426}]},
#                    {'geometry': [{'x': 770, 'y': 162},
#                                  {'x': 770, 'y': 220},
#                                  {'x': 838, 'y': 220},
#                                  {'x': 838, 'y': 162}]},
#                    {'geometry': [{'x': 654, 'y': 136},
#                                  {'x': 654, 'y': 182},
#                                  {'x': 703, 'y': 182},
#                                  {'x': 703, 'y': 136}]},
#                    {'geometry': [{'x': 585, 'y': 83},
#                                  {'x': 585, 'y': 115},
#                                  {'x': 623, 'y': 115},
#                                  {'x': 623, 'y': 83}]},
#                    {'geometry': [{'x': 652, 'y': 48},
#                                  {'x': 652, 'y': 71},
#                                  {'x': 683, 'y': 71},
#                                  {'x': 683, 'y': 48}]},
#                    {'geometry': [{'x': 732, 'y': 45},
#                                  {'x': 732, 'y': 68},
#                                  {'x': 762, 'y': 68},
#                                  {'x': 762, 'y': 45}]},
#                    {'geometry': [{'x': 439, 'y': 129},
#                                  {'x': 439, 'y': 190},
#                                  {'x': 515, 'y': 190},
#                                  {'x': 515, 'y': 129}]},
#                    {'geometry': [{'x': 89, 'y': 105},
#                                  {'x': 89, 'y': 160},
#                                  {'x': 177, 'y': 160},
#                                  {'x': 177, 'y': 105}]},
#                    {'geometry': [{'x': 437, 'y': 35},
#                                  {'x': 437, 'y': 11},
#                                  {'x': 471, 'y': 11},
#                                  {'x': 471, 'y': 35}]},
#                    {'geometry': [{'x': 735, 'y': 12},
#                                  {'x': 735, 'y': 0},
#                                  {'x': 754, 'y': 0},
#                                  {'x': 754, 'y': 12}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_7.jpg?alt=media&token=8fd902b0-c5bd-4881-b055-9dd658d39ba1',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 65.278,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcffp9xwu1a0797up2cio7p'}
# {'Agreement': None,
#  'Created At': '2019-01-25T19:16:54.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqo317w0anv29hrjbtb',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_8.jpg',
#  'ID': 'cjrcfgthbyjwv0896lgqe3g7i',
#  'Label': {'Car': [{'geometry': [{'x': 627, 'y': 529},
#                                  {'x': 627, 'y': 720},
#                                  {'x': 800, 'y': 720},
#                                  {'x': 800, 'y': 529}]},
#                    {'geometry': [{'x': 132, 'y': 567},
#                                  {'x': 132, 'y': 393},
#                                  {'x': 339, 'y': 393},
#                                  {'x': 339, 'y': 567}]},
#                    {'geometry': [{'x': 838, 'y': 343},
#                                  {'x': 838, 'y': 259},
#                                  {'x': 932, 'y': 259},
#                                  {'x': 932, 'y': 343}]},
#                    {'geometry': [{'x': 752, 'y': 114},
#                                  {'x': 752, 'y': 160},
#                                  {'x': 805, 'y': 160},
#                                  {'x': 805, 'y': 114}]},
#                    {'geometry': [{'x': 655, 'y': 101},
#                                  {'x': 655, 'y': 138},
#                                  {'x': 696, 'y': 138},
#                                  {'x': 696, 'y': 101}]},
#                    {'geometry': [{'x': 491, 'y': 89},
#                                  {'x': 491, 'y': 132},
#                                  {'x': 547, 'y': 132},
#                                  {'x': 547, 'y': 89}]},
#                    {'geometry': [{'x': 596, 'y': 88},
#                                  {'x': 596, 'y': 59},
#                                  {'x': 629, 'y': 59},
#                                  {'x': 629, 'y': 88}]},
#                    {'geometry': [{'x': 653, 'y': 57},
#                                  {'x': 653, 'y': 35},
#                                  {'x': 680, 'y': 35},
#                                  {'x': 680, 'y': 57}]},
#                    {'geometry': [{'x': 729, 'y': 54},
#                                  {'x': 729, 'y': 33},
#                                  {'x': 753, 'y': 33},
#                                  {'x': 753, 'y': 54}]},
#                    {'geometry': [{'x': 404, 'y': 53},
#                                  {'x': 404, 'y': 24},
#                                  {'x': 445, 'y': 24},
#                                  {'x': 445, 'y': 53}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_8.jpg?alt=media&token=5677d9fc-45a6-43e5-b48f-9e20e984798a',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 50.308,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrcfgthbyjwv0896lgqe3g7i'}
# {'Agreement': None,
#  'Created At': '2019-02-05T06:24:23.000Z',
#  'Created By': 'sakibreza1@gmail.com',
#  'DataRow ID': 'cjrceuyqp31800anvj753n3lo',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_9.jpg',
#  'ID': 'cjrrdpptkivs50898cpxm4nmp',
#  'Label': {'Car': [{'geometry': [{'x': 350, 'y': 210},
#                                  {'x': 350, 'y': 317},
#                                  {'x': 462, 'y': 317},
#                                  {'x': 462, 'y': 210}]},
#                    {'geometry': [{'x': 631, 'y': 298},
#                                  {'x': 631, 'y': 437},
#                                  {'x': 751, 'y': 437},
#                                  {'x': 751, 'y': 298}]},
#                    {'geometry': [{'x': 793, 'y': 165},
#                                  {'x': 793, 'y': 247},
#                                  {'x': 881, 'y': 247},
#                                  {'x': 881, 'y': 165}]},
#                    {'geometry': [{'x': 517, 'y': 50},
#                                  {'x': 517, 'y': 99},
#                                  {'x': 571, 'y': 99},
#                                  {'x': 571, 'y': 50}]},
#                    {'geometry': [{'x': 648, 'y': 70},
#                                  {'x': 648, 'y': 115},
#                                  {'x': 695, 'y': 115},
#                                  {'x': 695, 'y': 70}]},
#                    {'geometry': [{'x': 735, 'y': 77},
#                                  {'x': 735, 'y': 123},
#                                  {'x': 789, 'y': 123},
#                                  {'x': 789, 'y': 77}]},
#                    {'geometry': [{'x': 600, 'y': 38},
#                                  {'x': 600, 'y': 70},
#                                  {'x': 639, 'y': 70},
#                                  {'x': 639, 'y': 38}]},
#                    {'geometry': [{'x': 352, 'y': 37},
#                                  {'x': 352, 'y': 82},
#                                  {'x': 410, 'y': 82},
#                                  {'x': 410, 'y': 37}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_9.jpg?alt=media&token=1ac022df-74b0-452f-a44d-f0101fe93ada',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 82.513,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjrrdpptkivs50898cpxm4nmp'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:03:58.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp31840anvfl2lsz8w',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_10.jpg',
#  'ID': 'cjs8mk0wqkfn90898j8i23rmx',
#  'Label': {'Car': [{'geometry': [{'x': 644, 'y': 203},
#                                  {'x': 644, 'y': 278},
#                                  {'x': 723, 'y': 278},
#                                  {'x': 723, 'y': 203}]},
#                    {'geometry': [{'x': 780, 'y': 120},
#                                  {'x': 780, 'y': 169},
#                                  {'x': 837, 'y': 169},
#                                  {'x': 837, 'y': 120}]},
#                    {'geometry': [{'x': 441, 'y': 133},
#                                  {'x': 441, 'y': 194},
#                                  {'x': 513, 'y': 194},
#                                  {'x': 513, 'y': 133}]},
#                    {'geometry': [{'x': 293, 'y': 59},
#                                  {'x': 293, 'y': 106},
#                                  {'x': 360, 'y': 106},
#                                  {'x': 360, 'y': 59}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_10.jpg?alt=media&token=b29e2b3c-73b5-461c-8225-ba63042231d8',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 4801.36,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mk0wqkfn90898j8i23rmx'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:04:31.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp31880anvwi138x6e',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_11.jpg',
#  'ID': 'cjs8mkps8kgjq0898s2al4s62',
#  'Label': {'Car': [{'geometry': [{'x': 194, 'y': 96},
#                                  {'x': 194, 'y': 153},
#                                  {'x': 288, 'y': 153},
#                                  {'x': 288, 'y': 96}]},
#                    {'geometry': [{'x': 632, 'y': 435},
#                                  {'x': 632, 'y': 587},
#                                  {'x': 748, 'y': 587},
#                                  {'x': 748, 'y': 435}]},
#                    {'geometry': [{'x': 901, 'y': 501},
#                                  {'x': 901, 'y': 711},
#                                  {'x': 1118, 'y': 711},
#                                  {'x': 1118, 'y': 501}]},
#                    {'geometry': [{'x': 645, 'y': 143},
#                                  {'x': 645, 'y': 198},
#                                  {'x': 711, 'y': 198},
#                                  {'x': 711, 'y': 143}]},
#                    {'geometry': [{'x': 771, 'y': 90},
#                                  {'x': 771, 'y': 128},
#                                  {'x': 811, 'y': 128},
#                                  {'x': 811, 'y': 90}]},
#                    {'geometry': [{'x': 491, 'y': 92},
#                                  {'x': 491, 'y': 136},
#                                  {'x': 545, 'y': 136},
#                                  {'x': 545, 'y': 92}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_11.jpg?alt=media&token=631ef1bc-1005-4359-85be-612b28091fb3',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 31.135,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mkps8kgjq0898s2al4s62'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:04:57.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp318c0anvefwd7qyq',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_12.jpg',
#  'ID': 'cjs8mlabok9a40b471zd6onil',
#  'Label': {'Car': [{'geometry': [{'x': 29, 'y': 152},
#                                  {'x': 29, 'y': 235},
#                                  {'x': 166, 'y': 235},
#                                  {'x': 166, 'y': 152}]},
#                    {'geometry': [{'x': 639, 'y': 261},
#                                  {'x': 639, 'y': 336},
#                                  {'x': 720, 'y': 336},
#                                  {'x': 720, 'y': 261}]},
#                    {'geometry': [{'x': 817, 'y': 298},
#                                  {'x': 817, 'y': 395},
#                                  {'x': 932, 'y': 395},
#                                  {'x': 932, 'y': 298}]},
#                    {'geometry': [{'x': 255, 'y': 594},
#                                  {'x': 255, 'y': 720},
#                                  {'x': 464, 'y': 720},
#                                  {'x': 464, 'y': 594}]},
#                    {'geometry': [{'x': 652, 'y': 108},
#                                  {'x': 652, 'y': 145},
#                                  {'x': 697, 'y': 145},
#                                  {'x': 697, 'y': 108}]},
#                    {'geometry': [{'x': 759, 'y': 63},
#                                  {'x': 759, 'y': 96},
#                                  {'x': 794, 'y': 96},
#                                  {'x': 794, 'y': 63}]},
#                    {'geometry': [{'x': 524, 'y': 63},
#                                  {'x': 524, 'y': 94},
#                                  {'x': 565, 'y': 94},
#                                  {'x': 565, 'y': 63}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_12.jpg?alt=media&token=e05bd48e-140c-4735-af6a-d8759ce36b55',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 25.692,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mlabok9a40b471zd6onil'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:05:21.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp318g0anvdg41rly6',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_13.jpg',
#  'ID': 'cjs8mlsemkhr30898a84f1kbr',
#  'Label': {'Car': [{'geometry': [{'x': 438, 'y': 313},
#                                  {'x': 438, 'y': 418},
#                                  {'x': 546, 'y': 418},
#                                  {'x': 546, 'y': 313}]},
#                    {'geometry': [{'x': 647, 'y': 169},
#                                  {'x': 647, 'y': 228},
#                                  {'x': 706, 'y': 228},
#                                  {'x': 706, 'y': 169}]},
#                    {'geometry': [{'x': 776, 'y': 194},
#                                  {'x': 776, 'y': 260},
#                                  {'x': 852, 'y': 260},
#                                  {'x': 852, 'y': 194}]},
#                    {'geometry': [{'x': 649, 'y': 73},
#                                  {'x': 649, 'y': 111},
#                                  {'x': 698, 'y': 111},
#                                  {'x': 698, 'y': 73}]},
#                    {'geometry': [{'x': 542, 'y': 41},
#                                  {'x': 542, 'y': 69},
#                                  {'x': 582, 'y': 69},
#                                  {'x': 582, 'y': 41}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_13.jpg?alt=media&token=4d489871-a8d8-4d39-9519-2bb6e19fc8bb',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 21.93,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mlsemkhr30898a84f1kbr'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:05:48.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp318k0anvfzp9ah9b',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_14.jpg',
#  'ID': 'cjs8mmd11kad70b47doe4rzp8',
#  'Label': {'Car': [{'geometry': [{'x': 509, 'y': 190},
#                                  {'x': 509, 'y': 256},
#                                  {'x': 583, 'y': 256},
#                                  {'x': 583, 'y': 190}]},
#                    {'geometry': [{'x': 649, 'y': 124},
#                                  {'x': 649, 'y': 161},
#                                  {'x': 698, 'y': 161},
#                                  {'x': 698, 'y': 124}]},
#                    {'geometry': [{'x': 753, 'y': 135},
#                                  {'x': 753, 'y': 185},
#                                  {'x': 811, 'y': 185},
#                                  {'x': 811, 'y': 135}]},
#                    {'geometry': [{'x': 653, 'y': 54},
#                                  {'x': 653, 'y': 86},
#                                  {'x': 690, 'y': 86},
#                                  {'x': 690, 'y': 54}]},
#                    {'geometry': [{'x': 561, 'y': 24},
#                                  {'x': 561, 'y': 49},
#                                  {'x': 592, 'y': 49},
#                                  {'x': 592, 'y': 24}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_14.jpg?alt=media&token=bb24cf7f-b23a-4829-8932-05b564d79103',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 26.042,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mmd11kad70b47doe4rzp8'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:06:02.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp318o0anvepzj2uqn',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_15.jpg',
#  'ID': 'cjs8mmohekie60898bun9ngys',
#  'Label': {'Car': [{'geometry': [{'x': 549, 'y': 124},
#                                  {'x': 549, 'y': 174},
#                                  {'x': 600, 'y': 174},
#                                  {'x': 600, 'y': 124}]},
#                    {'geometry': [{'x': 651, 'y': 90},
#                                  {'x': 651, 'y': 120},
#                                  {'x': 694, 'y': 120},
#                                  {'x': 694, 'y': 90}]},
#                    {'geometry': [{'x': 738, 'y': 95},
#                                  {'x': 738, 'y': 136},
#                                  {'x': 781, 'y': 136},
#                                  {'x': 781, 'y': 95}]},
#                    {'geometry': [{'x': 653, 'y': 42},
#                                  {'x': 653, 'y': 71},
#                                  {'x': 689, 'y': 71},
#                                  {'x': 689, 'y': 42}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_15.jpg?alt=media&token=fc881aca-15fb-4f61-83c0-80a837801a13',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 14.135,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mmohekie60898bun9ngys'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:06:23.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp318s0anvzl9n24oe',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_16.jpg',
#  'ID': 'cjs8mn48pkax60b476inn43sz',
#  'Label': {'Car': [{'geometry': [{'x': 573, 'y': 88},
#                                  {'x': 573, 'y': 121},
#                                  {'x': 612, 'y': 121},
#                                  {'x': 612, 'y': 88}]},
#                    {'geometry': [{'x': 653, 'y': 63},
#                                  {'x': 653, 'y': 95},
#                                  {'x': 685, 'y': 95},
#                                  {'x': 685, 'y': 63}]},
#                    {'geometry': [{'x': 728, 'y': 73},
#                                  {'x': 728, 'y': 106},
#                                  {'x': 765, 'y': 106},
#                                  {'x': 765, 'y': 73}]},
#                    {'geometry': [{'x': 375, 'y': 41},
#                                  {'x': 375, 'y': 69},
#                                  {'x': 414, 'y': 69},
#                                  {'x': 414, 'y': 41}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_16.jpg?alt=media&token=a4590fba-420f-4f0b-bd17-db0c3510cf02',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 19.748,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mn48pkax60b476inn43sz'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:07:07.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp318w0anvxdjjpuw9',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_17.jpg',
#  'ID': 'cjs8mo2nbkbzu0b47z5mch5qx',
#  'Label': {'Car': [{'geometry': [{'x': 321, 'y': 62},
#                                  {'x': 321, 'y': 98},
#                                  {'x': 368, 'y': 98},
#                                  {'x': 368, 'y': 62}]},
#                    {'geometry': [{'x': 585, 'y': 62},
#                                  {'x': 585, 'y': 91},
#                                  {'x': 620, 'y': 91},
#                                  {'x': 620, 'y': 62}]},
#                    {'geometry': [{'x': 1058, 'y': 618},
#                                  {'x': 1058, 'y': 713},
#                                  {'x': 1277, 'y': 713},
#                                  {'x': 1277, 'y': 618}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_17.jpg?alt=media&token=2382ec92-00f6-46fe-ae69-271123f6e647',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 43.918,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mo2nbkbzu0b47z5mch5qx'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:07:25.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp31900anvhjpgob3q',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_18.jpg',
#  'ID': 'cjs8mogjhkk6a0898znjwewaj',
#  'Label': {'Car': [{'geometry': [{'x': 434, 'y': 348},
#                                  {'x': 434, 'y': 476},
#                                  {'x': 563, 'y': 476},
#                                  {'x': 563, 'y': 348}]},
#                    {'geometry': [{'x': 916, 'y': 354},
#                                  {'x': 916, 'y': 468},
#                                  {'x': 1049, 'y': 468},
#                                  {'x': 1049, 'y': 354}]},
#                    {'geometry': [{'x': 234, 'y': 96},
#                                  {'x': 234, 'y': 137},
#                                  {'x': 298, 'y': 137},
#                                  {'x': 298, 'y': 96}]},
#                    {'geometry': [{'x': 241, 'y': 34},
#                                  {'x': 241, 'y': 67},
#                                  {'x': 289, 'y': 67},
#                                  {'x': 289, 'y': 34}]},
#                    {'geometry': [{'x': 362, 'y': 22},
#                                  {'x': 362, 'y': 42},
#                                  {'x': 397, 'y': 42},
#                                  {'x': 397, 'y': 22}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_18.jpg?alt=media&token=884c4c04-f6ec-419c-afc0-fb4633693a5f',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 17.334,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mogjhkk6a0898znjwewaj'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:07:41.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp31940anv54q5opvq',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_19.jpg',
#  'ID': 'cjs8mosc5kcm30b474m3ndieh',
#  'Label': {'Car': [{'geometry': [{'x': 515, 'y': 208},
#                                  {'x': 515, 'y': 282},
#                                  {'x': 596, 'y': 282},
#                                  {'x': 596, 'y': 208}]},
#                    {'geometry': [{'x': 854, 'y': 232},
#                                  {'x': 854, 'y': 300},
#                                  {'x': 938, 'y': 300},
#                                  {'x': 938, 'y': 232}]},
#                    {'geometry': [{'x': 88, 'y': 150},
#                                  {'x': 88, 'y': 211},
#                                  {'x': 189, 'y': 211},
#                                  {'x': 189, 'y': 150}]},
#                    {'geometry': [{'x': 164, 'y': 57},
#                                  {'x': 164, 'y': 94},
#                                  {'x': 226, 'y': 94},
#                                  {'x': 226, 'y': 57}]},
#                    {'geometry': [{'x': 323, 'y': 36},
#                                  {'x': 323, 'y': 58},
#                                  {'x': 364, 'y': 58},
#                                  {'x': 364, 'y': 36}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_19.jpg?alt=media&token=1c855cb3-d4ce-4560-9265-f76fd5b3155f',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 14.609,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mosc5kcm30b474m3ndieh'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:07:57.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp31980anvlpl1k79j',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_20.jpg',
#  'ID': 'cjs8mp4sxkcyg0b471if9msdq',
#  'Label': {'Car': [{'geometry': [{'x': 556, 'y': 135},
#                                  {'x': 556, 'y': 193},
#                                  {'x': 614, 'y': 193},
#                                  {'x': 614, 'y': 135}]},
#                    {'geometry': [{'x': 818, 'y': 162},
#                                  {'x': 818, 'y': 210},
#                                  {'x': 881, 'y': 210},
#                                  {'x': 881, 'y': 162}]},
#                    {'geometry': [{'x': 454, 'y': 338},
#                                  {'x': 454, 'y': 455},
#                                  {'x': 569, 'y': 455},
#                                  {'x': 569, 'y': 338}]},
#                    {'geometry': [{'x': 61, 'y': 78},
#                                  {'x': 61, 'y': 135},
#                                  {'x': 139, 'y': 135},
#                                  {'x': 139, 'y': 78}]},
#                    {'geometry': [{'x': 277, 'y': 50},
#                                  {'x': 277, 'y': 78},
#                                  {'x': 326, 'y': 78},
#                                  {'x': 326, 'y': 50}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_20.jpg?alt=media&token=1977a5a4-156e-4acb-bb54-1912f05a77dd',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 15.475,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjs8mp4sxkcyg0b471if9msdq'}
# {'Agreement': None,
#  'Created At': '2019-02-17T08:08:09.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqp319c0anvhxqjwj0n',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_21.jpg',
#  'ID': 'cjs8mpdw5kd4m0b47k2ty8wx0',
#  'Label': {'Car': [{'geometry': [{'x': 524, 'y': 206},
# ...
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 11.142,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi4e9xku5h0728lspfwt66'}
# {'Agreement': None,
#  'Created At': '2019-02-20T17:59:00.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqs31h40anvrznbgfq1',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_91.jpg',
#  'ID': 'cjsdi4s3xlaua08126vz35w6x',
#  'Label': {'Car': [{'geometry': [{'x': 529, 'y': 194},
#                                  {'x': 529, 'y': 252},
#                                  {'x': 595, 'y': 252},
#                                  {'x': 595, 'y': 194}]},
#                    {'geometry': [{'x': 637, 'y': 385},
#                                  {'x': 637, 'y': 529},
#                                  {'x': 759, 'y': 529},
#                                  {'x': 759, 'y': 385}]},
#                    {'geometry': [{'x': 838, 'y': 401},
#                                  {'x': 838, 'y': 554},
#                                  {'x': 994, 'y': 554},
#                                  {'x': 994, 'y': 401}]},
#                    {'geometry': [{'x': 285, 'y': 78},
#                                  {'x': 285, 'y': 113},
#                                  {'x': 336, 'y': 113},
#                                  {'x': 336, 'y': 78}]},
#                    {'geometry': [{'x': 756, 'y': 95},
#                                  {'x': 756, 'y': 143},
#                                  {'x': 805, 'y': 143},
#                                  {'x': 805, 'y': 95}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_91.jpg?alt=media&token=a7791bb4-a85e-4ce5-98f1-431643f03c1d',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 16.957,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi4s3xlaua08126vz35w6x'}
# {'Agreement': None,
#  'Created At': '2019-02-20T17:59:34.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqs31h80anv83pmsnzf',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_92.jpg',
#  'ID': 'cjsdi5ipelb6y0812nxi7jg00',
#  'Label': {'Car': [{'geometry': [{'x': 326, 'y': 508},
#                                  {'x': 326, 'y': 720},
#                                  {'x': 493, 'y': 720},
#                                  {'x': 493, 'y': 508}]},
#                    {'geometry': [{'x': 785, 'y': 264},
#                                  {'x': 785, 'y': 351},
#                                  {'x': 887, 'y': 351},
#                                  {'x': 887, 'y': 264}]},
#                    {'geometry': [{'x': 645, 'y': 238},
#                                  {'x': 645, 'y': 321},
#                                  {'x': 724, 'y': 321},
#                                  {'x': 724, 'y': 238}]},
#                    {'geometry': [{'x': 559, 'y': 131},
#                                  {'x': 559, 'y': 172},
#                                  {'x': 612, 'y': 172},
#                                  {'x': 612, 'y': 131}]},
#                    {'geometry': [{'x': 181, 'y': 116},
#                                  {'x': 181, 'y': 166},
#                                  {'x': 259, 'y': 166},
#                                  {'x': 259, 'y': 116}]},
#                    {'geometry': [{'x': 744, 'y': 69},
#                                  {'x': 744, 'y': 110},
#                                  {'x': 789, 'y': 110},
#                                  {'x': 789, 'y': 69}]},
#                    {'geometry': [{'x': 165, 'y': 86},
#                                  {'x': 165, 'y': 128},
#                                  {'x': 231, 'y': 128},
#                                  {'x': 231, 'y': 86}]},
#                    {'geometry': [{'x': 110, 'y': 58},
#                                  {'x': 110, 'y': 95},
#                                  {'x': 170, 'y': 95},
#                                  {'x': 170, 'y': 58}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_92.jpg?alt=media&token=6a3d8530-1123-4296-9afe-48e04fd682a5',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 31.295,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi5ipelb6y0812nxi7jg00'}
# {'Agreement': None,
#  'Created At': '2019-02-20T18:00:09.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqs31hc0anvrxgqfntp',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_93.jpg',
#  'ID': 'cjsdi69jskv5e0728bcaq386e',
#  'Label': {'Car': [{'geometry': [{'x': 583, 'y': 92},
#                                  {'x': 583, 'y': 123},
#                                  {'x': 620, 'y': 123},
#                                  {'x': 620, 'y': 92}]},
#                    {'geometry': [{'x': 653, 'y': 158},
#                                  {'x': 653, 'y': 216},
#                                  {'x': 714, 'y': 216},
#                                  {'x': 714, 'y': 158}]},
#                    {'geometry': [{'x': 760, 'y': 182},
#                                  {'x': 760, 'y': 236},
#                                  {'x': 827, 'y': 236},
#                                  {'x': 827, 'y': 182}]},
#                    {'geometry': [{'x': 884, 'y': 425},
#                                  {'x': 884, 'y': 602},
#                                  {'x': 1049, 'y': 602},
#                                  {'x': 1049, 'y': 425}]},
#                    {'geometry': [{'x': 475, 'y': 278},
#                                  {'x': 475, 'y': 368},
#                                  {'x': 566, 'y': 368},
#                                  {'x': 566, 'y': 278}]},
#                    {'geometry': [{'x': 25, 'y': 182},
#                                  {'x': 25, 'y': 249},
#                                  {'x': 133, 'y': 249},
#                                  {'x': 133, 'y': 182}]},
#                    {'geometry': [{'x': 24, 'y': 131},
#                                  {'x': 24, 'y': 183},
#                                  {'x': 131, 'y': 183},
#                                  {'x': 131, 'y': 131}]},
#                    {'geometry': [{'x': 298, 'y': 63},
#                                  {'x': 298, 'y': 102},
#                                  {'x': 351, 'y': 102},
#                                  {'x': 351, 'y': 63}]},
#                    {'geometry': [{'x': 94, 'y': 88},
#                                  {'x': 94, 'y': 124},
#                                  {'x': 169, 'y': 124},
#                                  {'x': 169, 'y': 88}]},
#                    {'geometry': [{'x': 78, 'y': 124},
#                                  {'x': 78, 'y': 82},
#                                  {'x': 24, 'y': 82},
#                                  {'x': 24, 'y': 124}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_93.jpg?alt=media&token=93ce0796-8373-4e1d-b8b3-be34274d0eaf',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 33.521,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi69jskv5e0728bcaq386e'}
# {'Agreement': None,
#  'Created At': '2019-02-20T18:00:32.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqs31hg0anvbnv3es33',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_94.jpg',
#  'ID': 'cjsdi6rjrkvnb0728iktftzfi',
#  'Label': {'Car': [{'geometry': [{'x': 530, 'y': 172},
#                                  {'x': 530, 'y': 226},
#                                  {'x': 591, 'y': 226},
#                                  {'x': 591, 'y': 172}]},
#                    {'geometry': [{'x': 825, 'y': 282},
#                                  {'x': 825, 'y': 369},
#                                  {'x': 928, 'y': 369},
#                                  {'x': 928, 'y': 282}]},
#                    {'geometry': [{'x': 276, 'y': 571},
#                                  {'x': 276, 'y': 720},
#                                  {'x': 483, 'y': 720},
#                                  {'x': 483, 'y': 571}]},
#                    {'geometry': [{'x': 657, 'y': 110},
#                                  {'x': 657, 'y': 156},
#                                  {'x': 706, 'y': 156},
#                                  {'x': 706, 'y': 110}]},
#                    {'geometry': [{'x': 742, 'y': 133},
#                                  {'x': 742, 'y': 175},
#                                  {'x': 796, 'y': 175},
#                                  {'x': 796, 'y': 133}]},
#                    {'geometry': [{'x': 211, 'y': 98},
#                                  {'x': 211, 'y': 144},
#                                  {'x': 286, 'y': 144},
#                                  {'x': 286, 'y': 98}]},
#                    {'geometry': [{'x': 166, 'y': 59},
#                                  {'x': 166, 'y': 92},
#                                  {'x': 222, 'y': 92},
#                                  {'x': 222, 'y': 59}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_94.jpg?alt=media&token=8241fd48-bd73-4ad6-ab76-93efbf96b9f1',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 21.224,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi6rjrkvnb0728iktftzfi'}
# {'Agreement': None,
#  'Created At': '2019-02-20T18:00:58.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqs31hk0anvxptrssj1',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_95.jpg',
#  'ID': 'cjsdi7bh7lcy5081293feuoje',
#  'Label': {'Car': [{'geometry': [{'x': 559, 'y': 111},
#                                  {'x': 559, 'y': 153},
#                                  {'x': 606, 'y': 153},
#                                  {'x': 606, 'y': 111}]},
#                    {'geometry': [{'x': 658, 'y': 83},
#                                  {'x': 658, 'y': 119},
#                                  {'x': 699, 'y': 119},
#                                  {'x': 699, 'y': 83}]},
#                    {'geometry': [{'x': 459, 'y': 300},
#                                  {'x': 459, 'y': 402},
#                                  {'x': 563, 'y': 402},
#                                  {'x': 563, 'y': 300}]},
#                    {'geometry': [{'x': 797, 'y': 197},
#                                  {'x': 797, 'y': 256},
#                                  {'x': 867, 'y': 256},
#                                  {'x': 867, 'y': 197}]},
#                    {'geometry': [{'x': 730, 'y': 102},
#                                  {'x': 730, 'y': 133},
#                                  {'x': 775, 'y': 133},
#                                  {'x': 775, 'y': 102}]},
#                    {'geometry': [{'x': 78, 'y': 140},
#                                  {'x': 78, 'y': 210},
#                                  {'x': 179, 'y': 210},
#                                  {'x': 179, 'y': 140}]},
#                    {'geometry': [{'x': 65, 'y': 91},
#                                  {'x': 65, 'y': 136},
#                                  {'x': 141, 'y': 136},
#                                  {'x': 141, 'y': 91}]},
#                    {'geometry': [{'x': 350, 'y': 49},
#                                  {'x': 350, 'y': 79},
#                                  {'x': 391, 'y': 79},
#                                  {'x': 391, 'y': 49}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_95.jpg?alt=media&token=a0c1e1da-fb46-4b43-962a-a1214bb675d6',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 24.71,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi7bh7lcy5081293feuoje'}
# {'Agreement': None,
#  'Created At': '2019-02-20T18:01:20.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqs31ho0anvthw0f7hn',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_96.jpg',
#  'ID': 'cjsdi7s4hkwq30728kjwo97dm',
#  'Label': {'Car': [{'geometry': [{'x': 525, 'y': 185},
#                                  {'x': 525, 'y': 244},
#                                  {'x': 590, 'y': 244},
#                                  {'x': 590, 'y': 185}]},
#                    {'geometry': [{'x': 777, 'y': 140},
#                                  {'x': 777, 'y': 187},
#                                  {'x': 831, 'y': 187},
#                                  {'x': 831, 'y': 140}]},
#                    {'geometry': [{'x': 722, 'y': 77},
#                                  {'x': 722, 'y': 107},
#                                  {'x': 761, 'y': 107},
#                                  {'x': 761, 'y': 77}]},
#                    {'geometry': [{'x': 579, 'y': 79},
#                                  {'x': 579, 'y': 111},
#                                  {'x': 620, 'y': 111},
#                                  {'x': 620, 'y': 79}]},
#                    {'geometry': [{'x': 290, 'y': 71},
#                                  {'x': 290, 'y': 110},
#                                  {'x': 342, 'y': 110},
#                                  {'x': 342, 'y': 71}]},
#                    {'geometry': [{'x': 657, 'y': 63},
#                                  {'x': 657, 'y': 91},
#                                  {'x': 697, 'y': 91},
#                                  {'x': 697, 'y': 63}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_96.jpg?alt=media&token=33bca7f8-8078-4575-8334-f086244474a2',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 20.633,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi7s4hkwq30728kjwo97dm'}
# {'Agreement': None,
#  'Created At': '2019-02-20T18:01:35.000Z',
#  'Created By': 'insaneshadowzaman@gmail.com',
#  'DataRow ID': 'cjrceuyqs31hs0anvt4w7zun0',
#  'Dataset Name': 'High Road 1',
#  'External ID': 'img_97.jpg',
#  'ID': 'cjsdi84a1kx3u0728y1jyox63',
#  'Label': {'Car': [{'geometry': [{'x': 556, 'y': 127},
#                                  {'x': 556, 'y': 164},
#                                  {'x': 608, 'y': 164},
#                                  {'x': 608, 'y': 127}]},
#                    {'geometry': [{'x': 764, 'y': 107},
#                                  {'x': 764, 'y': 144},
#                                  {'x': 810, 'y': 144},
#                                  {'x': 810, 'y': 107}]},
#                    {'geometry': [{'x': 193, 'y': 108},
#                                  {'x': 193, 'y': 156},
#                                  {'x': 267, 'y': 156},
#                                  {'x': 267, 'y': 108}]},
#                    {'geometry': [{'x': 591, 'y': 54},
#                                  {'x': 591, 'y': 79},
#                                  {'x': 624, 'y': 79},
#                                  {'x': 624, 'y': 54}]},
#                    {'geometry': [{'x': 714, 'y': 53},
#                                  {'x': 714, 'y': 83},
#                                  {'x': 748, 'y': 83},
#                                  {'x': 748, 'y': 53}]}]},
#  'Labeled Data': 'https://firebasestorage.googleapis.com/v0/b/labelbox-193903.appspot.com/o/cjnuyzms6j2d408043ivrlrle%2F4ea825ed-b3bc-44ec-92bb-703d9a375fe3%2Fimg_97.jpg?alt=media&token=9d550527-e1fd-4f16-a10a-9c15bc95612f',
#  'Project Name': 'Car and Bike labeling',
#  'Reviews': [],
#  'Seconds to Label': 14.98,
#  'View Label': 'https://image-segmentation-v4.labelbox.com?project=cjrcevze2xyfw0896citornw9&label=cjsdi84a1kx3u0728y1jyox63'}

# %% [markdown]
# ## Datasets

# %%
# Input Images
num_images = 98
image = np.zeros((num_images, 720, 1280, 3))
for i in range(num_images):
    image[i, :, :, :] = cv2.imread("highway-cctv-footage-images/input_images/img_{}.jpg".format(str(i)), cv2.IMREAD_UNCHANGED)
print(image.shape)

# Output Bounding Boxes Informations
# Out:
# (98, 720, 1280, 3)

# %% [markdown]
# ## Model

# %%
def create_model():
    inputs = keras.Input(shape=(720, 1280, 3))
    conv1 = keras.layers.Conv2D(filters=64, kernel_size=7, activation=tf.nn.relu, padding='SAME')(inputs)
    pool1 = keras.layers.MaxPool2D(padding='SAME')(conv1)
    conv2 = keras.layers.Conv2D(filters=64, kernel_size=3, activation=tf.nn.relu, padding='SAME')(pool1)
    pool2 = keras.layers.MaxPool2D(padding='SAME')(conv2)
    conv3 = keras.layers.Conv2D(filters=64, kernel_size=3, activation=tf.nn.relu, padding='SAME')(pool2)
    pool3 = keras.layers.MaxPool2D(padding='SAME')(conv3)
    conv4 = keras.layers.Conv2D(filters=64, kernel_size=3, activation=tf.nn.relu, padding='SAME')(pool3)
    pool4 = keras.layers.MaxPool2D(padding='SAME')(conv4)
    conv5 = keras.layers.Conv2D(filters=64, kernel_size=3, activation=tf.nn.relu, padding='SAME')(pool4)
    pool5 = keras.layers.MaxPool2D(pool_size = (5,5), padding='SAME')(conv5)
    pool5_flat = keras.layers.Flatten()(pool5)
    dense1 = keras.layers.Dense(units = 256, activation=tf.nn.relu)(pool5_flat)
    drop1 = keras.layers.Dropout(0.4)(dense1)
    dense2_1 = keras.layers.Dense(16 * 9 * 5, activation=tf.nn.relu)(drop1)
    dense2_2 = keras.layers.Dense(16 * 9 * 1, activation=tf.nn.sigmoid)(drop1)
    resh1_1 = keras.layers.Reshape((9, 16, 5))(dense2_1)
    resh1_2 = keras.layers.Reshape((9, 16, 1))(dense2_2)
    outputs = keras.layers.Concatenate(axis=-1)([resh1_1, resh1_2])
    return keras.Model(inputs = inputs, outputs = outputs)

model = create_model()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 720, 1280, 3) 0
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 720, 1280, 64 9472        input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 360, 640, 64) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 360, 640, 64) 36928       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 180, 320, 64) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 180, 320, 64) 36928       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 90, 160, 64)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 90, 160, 64)  36928       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 45, 80, 64)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 45, 80, 64)   36928       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 9, 16, 64)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 9216)         0           max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          2359552     flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 720)          185040      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 144)          37008       dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 9, 16, 5)     0           dense_6[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 9, 16, 1)     0           dense_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 9, 16, 6)     0           reshape_2[0][0]
#                                                                  reshape_3[0][0]
# ==================================================================================================
# Total params: 2,738,784
# Trainable params: 2,738,784
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Loss function

# %%
def loss_fn(model, images, labels):
    logits = model(images, training=True)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(
            logits=logits, labels=labels))    
    return loss

# %% [markdown]
# ## Gradient 계산

# %%
def grad(model, images, labels):
    with tf.GradientTape() as tape:
        loss = loss_fn(model, images, labels)
    return tape.gradient(loss, model.variables)

# %% [markdown]
# ## 모델 정확도 계산

# %%
def evaluate(model, images, labels):
    logits = model(images, training=False)
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    return accuracy

# %% [markdown]
# ## Optimizer

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

# %% [markdown]
# ## Checkpoint

# %%
checkpoint = tf.train.Checkpoint(cnn=model)

# %% [markdown]
# ## Training

# %%
# train my model
import time

print('Learning started. It takes sometime.')
s_time = time.time()
for epoch in range(training_epochs):
    avg_loss = 0.
    avg_train_acc = 0.
    avg_test_acc = 0.
    train_step = 0
    test_step = 0
    
    for images, labels in train_dataset:
        grads = grad(model, images, labels)                
        optimizer.apply_gradients(zip(grads, model.variables))
        loss = loss_fn(model, images, labels)
        acc = evaluate(model, images, labels)
        avg_loss = avg_loss + loss
        avg_train_acc = avg_train_acc + acc
        train_step += 1
    avg_loss = avg_loss / train_step
    avg_train_acc = avg_train_acc / train_step
    
    for images, labels in test_dataset:        
        acc = evaluate(model, images, labels)        
        avg_test_acc = avg_test_acc + acc
        test_step += 1    
    avg_test_acc = avg_test_acc / test_step    

    print('Epoch:', '{}'.format(epoch + 1), 'loss =', '{:.8f}'.format(avg_loss), 
          'train accuracy = ', '{:.4f}'.format(avg_train_acc), 
          'test accuracy = ', '{:.4f}'.format(avg_test_acc))
    
    checkpoint.save(file_prefix=checkpoint_prefix)

e_time = time.time() - s_time
print('Learning Finished!')
print('{:5f} seconds'.format(e_time))
# Out:
# Learning started. It takes sometime.
# Epoch: 1 loss = 0.17266375 train accuracy =  0.9590 test accuracy =  0.9840
# Epoch: 3 loss = 0.03135390 train accuracy =  0.9936 test accuracy =  0.9922
# Epoch: 4 loss = 0.02327727 train accuracy =  0.9954 test accuracy =  0.9930
# Epoch: 5 loss = 0.01839644 train accuracy =  0.9967 test accuracy =  0.9935
# Epoch: 6 loss = 0.01527054 train accuracy =  0.9974 test accuracy =  0.9925
# Epoch: 7 loss = 0.01112090 train accuracy =  0.9982 test accuracy =  0.9921
# Epoch: 8 loss = 0.01158327 train accuracy =  0.9983 test accuracy =  0.9901
# Epoch: 9 loss = 0.00984489 train accuracy =  0.9986 test accuracy =  0.9928
# Epoch: 10 loss = 0.00841346 train accuracy =  0.9991 test accuracy =  0.9929
# Epoch: 11 loss = 0.00715333 train accuracy =  0.9992 test accuracy =  0.9926
# Epoch: 12 loss = 0.00622725 train accuracy =  0.9992 test accuracy =  0.9939
# Epoch: 13 loss = 0.00546163 train accuracy =  0.9993 test accuracy =  0.9922
# Epoch: 14 loss = 0.00527327 train accuracy =  0.9996 test accuracy =  0.9927
# Epoch: 15 loss = 0.00504138 train accuracy =  0.9995 test accuracy =  0.9933
# Learning Finished!
# 190.728890 seconds
